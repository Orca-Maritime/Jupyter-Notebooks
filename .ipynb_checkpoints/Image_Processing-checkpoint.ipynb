# %% [markdown]
# # Background Scrubber and Renaming
# >- This is the main script used for anyone with a mapped drive to the Millennium Machine.
# >- This script will rename, remove the band 4 background, and organize the processed geotiffs.
# >- The script will only work properly if the file name follows the correct naming convention, (SN0XXXX_YYYYMMDD).
# >- Rebuilding pyramids are needed after the background is removed; It is written in, but pyramids are not built, there is a function at the bottom of this notebook to help rebuild.

# %% [markdown]
# ## Import Libraries

# %%
import arcpy
from sys import argv
import shutil
import os
from os import path
from arcpy import env
from arcpy.sa import *
from datetime import datetime, date, timedelta

# %% [markdown]
# ## Region & Sensor Lists

# %%
region_list = [
    "ArabianGulf",
    "Baltics",
    "Chinhae", #Korea
    "ChonBuri", #Thailand
    "Guam",
    "Juneau", #USA
    "Kuwait",
    "PanamaCity", #USA
    "Pendleton", #USA
    "Pohang", #Korea
    "Providence", #USA
    'Saipan',
    "SanDiego",
    "Sasebo", #Japan
    "SCI",
    "Tasmania" # Australia
   
]

sensor_list = [
    'ATLAS',
    "JSF",
    "MST",
    'SSAM'
]

# %% [markdown]
# ## Declare Constant Variables

# %%
##Sets project to Current project; No need to alter
aprx = arcpy.mp.ArcGISProject("CURRENT")
aprx_map = aprx.listMaps("Sonar Imagery")[0]     

#Leave this "True"
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False


machine = input("Which Drive are you using; D or Y:  ")
machine = machine.lower()
while machine != "d" or machine != "y":
    machine = input("Please enter D or Y:  ")
    machine = machine.lower()


if machine == 'y':
    root_directory_path = r"Y:\TIFFs"
    unprocessed_directory_path = r"Y:\TIFFs\Unprocessed_Tiffs"
    processed_directory_path = r"Y:\TIFFs\Processed_Tiffs"
    failed_directory_path = r'Y:\Tiffs\Unprocessed_Tiffs\FAILED'
    ArcGIS_path = r"Y:\Image_Processing"
    utm_directory = r"Y:\Image_Processing\Projection Files\UTM"
    
elif machine == 'd':
    root_directory_path = r"D:\Image_Processing\TIFFs"
    unprocessed_directory_path = r"D:\Image_Processing\TIFFs\Unprocessed_Tiffs"
    processed_directory_path = r"D:\Image_Processing\TIFFs\Processed_Tiffs"
    failed_directory_path = r'D:\Image_Processing\TIFFs\FAILED'
    ArcGIS_path = r"D:\Image_Processing\Image_Processing"
    utm_directory = r"D:\Image_Processing\Image_Processing\Projection Files\UTM"


print(f"Available Regions: \n--") 
print(*region_list, sep='\n')
region = input("\nWhat Region are you processing?  ")
while region not in region_list:
    region = input("Please Enter a Valid Region: ")

print(f"\nAvailable Sensors: \n--") 
print(*sensor_list, sep='\n')
sensor = input("What Sensor are you processing?  ")
sensor = sensor.upper()
while sensor not in sensor_list:
    sensor = input("Please Enter a Valid Sensor: ")
    sensor = sensor.upper()
    
up_region_directory_path = os.path.join(unprocessed_directory_path, region)
up_sensor_directory_path = os.path.join(up_region_directory_path, sensor)

failed_region_path = os.path.join(failed_directory_path, region)
failed_sensor_path = os.path.join(failed_region_path, sensor)
# Out:
# Available Regions:
# --
# ArabianGulf
# Baltics
# Guam
# GulfOman
# Juneau
# Korea
# PanamaCity
# Pendleton
# Providence
# Saipan
# SanDiego
# SCI
# Tasmania
# Thailand
# What Region are you processing?  ArabianGulf
# Available Sensors:
# --
# ATLAS
# JSF
# MST
# SSAM
# What Region are you processing?  MST

# %% [markdown]
# ## Verify Geodatabase

# %%
arcpy.env.workspace = ArcGIS_path
gdb_list = arcpy.ListWorkspaces("*", 'FileGDB')
region_gdb_path = "Y:\\Image_Processing\\{}.gdb".format(region)
if region_gdb_path not in gdb_list:
    arcpy.CreateFileGDB_management(ArcGIS_path, region)
    print(f"-Creating '{region}.gdb'-")
else:
    print(f"-'{region}.gdb' Has already been created-")
aprx.defaultGeodatabase = region_gdb_path
# Out:
# -'ArabianGulf.gdb' Has already been created-

# %% [markdown]
# ## Rename Missions

# %%
mission_list = os.listdir(up_sensor_directory_path)
failed_rename_list = []
print("Renaming Missions")
for mission in mission_list:
    if mission != 'Thumbs.db':
        split = mission.split(".",1)
        extension = split[1]
        mission_name = split[0]
        rs = region+"_"+sensor
        if rs not in mission:
            print(f"--{mission}")
            altered_mission = "{}_{}_{}.{}".format(mission_name, region, sensor, extension)
            altered_mission_name = "{}_{}_{}".format(mission_name, region, sensor)
            old_path = "{}\{}".format(up_sensor_directory_path, mission)
            new_path = "{}\{}".format(up_sensor_directory_path, altered_mission)
            mission_path = new_path
            mission = altered_mission
            mission_name = altered_mission_name
            try:
                os.rename(old_path, new_path)
            except Exception as f:
                print(f"Unable to rename {mission}")
                failed_rename_list.append(altered_mission)
        
print("Done\n")   
print("Failed Rename: ")
print(*failed_rename_list, sep='\n')
# Out:
# Renaming Missions
# --Thumbs.db
# Done
#
# Failed Rename:

# %% [markdown]
# ## Verify Processed Directories

# %%
mission_list = os.listdir(up_sensor_directory_path)
for mission in mission_list:
    if mission != "Thumbs.db":
        mission_year = mission[8:12]
        mission_vehicle = mission[0:7]
        p_region_directory_path = os.path.join(processed_directory_path, region)
        p_sensor_directory_path = os.path.join(p_region_directory_path, sensor)
        p_vehicle_directory_path = os.path.join(p_sensor_directory_path, mission_vehicle)
        p_year_directory_path = os.path.join(p_vehicle_directory_path, mission_year)


        #Creating Project Directory
        pje = os.path.exists(p_region_directory_path)
        if pje == False:
            print(f'Creating {p_region_directory_path}')
            os.mkdir(p_region_directory_path)

        #Creating Sensor Directory
        sje = os.path.exists(p_sensor_directory_path)
        if sje == False:
            print(f'Creating {p_sensor_directory_path}')
            os.mkdir(p_sensor_directory_path)

        #Creating Vehicle Directory 
        vpe = os.path.exists(p_vehicle_directory_path)
        if vpe == False:
            print(f"**Creating {p_vehicle_directory_path}\n")
            os.mkdir(p_vehicle_directory_path)

        #Creating Year Directory
        ype = os.path.exists(p_year_directory_path)
        if ype == False:
            print(f"**Creating {p_year_directory_path}\n")
            os.mkdir(p_year_directory_path)
    
print("Done")
# Out:
# **Creating Y:\TIFFs\Processed_Tiffs\ArabianGulf\MST\Thumbs.
#
# **Creating Y:\TIFFs\Processed_Tiffs\ArabianGulf\MST\Thumbs.\b
#
# Done

# %% [markdown]
# ## Calculate Statistics
# This is important because many sonar files will fail due to no statistics being present. The Statistic files are .tfw and .TFWEx

# %%
print("Calculating Statistics")
mission_list = os.listdir(up_sensor_directory_path)
for mission in mission_list:
    extension = mission.split(".", 1)[1]
    mission_name = mission.split(".", 1)[0]
    mission_path = "{}\\{}".format(up_sensor_directory_path, mission)  
                   
    aux_file = "{}\\{}\\{}\\{}.tif.aux.xml".format(unprocessed_directory_path, region, sensor, mission_name)
    aux_file_exist = os.path.exists(aux_file)
    xml_file = "{}\\{}\\{}\\{}.tif.xml".format(unprocessed_directory_path, region, sensor, mission_name)
    xml_file_exist = os.path.exists(xml_file)
    
    if extension == "tif":
        #if aux_file_exist == False or xml_file_exist == False:
        print(f"^^Calculating Statistics {mission}")
        arcpy.management.CalculateStatistics(mission_path)

# %% [markdown]
# ## Reclassify Sonar Missions

# %%
#Reclass GDB Path; These will be used in Mosaic Datasets
reclass_gdb_path = r"Y:\Image_Processing\Reclass.gdb"

#Sets the Environment to the Default GDB
arcpy.env.workspace = region_gdb_path

#Gets updated mission list; These will have been renamed
mission_list = os.listdir(up_sensor_directory_path)

failed_list = []

print("Reclassifying Sonar Missions")
for mission in mission_list:
    extension = mission.split(".", 1)[1]
    mission_path = "{}\\{}".format(up_sensor_directory_path, mission)          
    if extension == 'tif':
        desc = arcpy.Describe(mission_path)
        polygon_name = "p_" + desc.baseName
        num_bands = desc.bandCount
        band_4 = mission_path + '\\Band_4'
        polygon_list = arcpy.ListFeatureClasses("p_*", "Polygon")
        out_poly = os.path.join(region_gdb_path, polygon_name)
        if reclass_name not in reclass_list:
            if num_bands < 4:
                in_raster = mission_path
            else:
                in_raster = band_4
            print(f"--{mission}")
            try:
                reclass = arcpy.sa.Reclassify(in_raster,
                                    "Value",
                                    "0 NODATA;1 255 2",
                                    "DATA")
                reclass.save(os.path.join(region_gdb_path, "reclass"))
                with arcpy.EnvManager(outputZFlag="Disabled", outputMFlag="Disabled"):
                arcpy.conversion.RasterToPolygon(reclass,
                                                 out_poly,
                                                 "SIMPLIFY",
                                                 "Value",
                                                 "MULTIPLE_OUTER_PART",
                                                 None)
                arcpy.management.AddFields(out_poly,
                                           [["Mission", 'TEXT', "Mission"],
                                            ["Region", 'TEXT', "Region"],
                                            ["InsideX", 'DOUBLE', "Inside X"],
                                            ["InsideY", 'DOUBLE', "Inside Y"],
                                            ["Grid", "TEXT", "Grid"]])
                arcpy.management.CalculateGeometryAttributes(out_poly,
                                                             [["InsideX", "INSIDE_X"],
                                                              ["InsideY", "INSIDE_Y"]],
                                                             '',
                                                             '', 
                                                             None,
                                                             "DD")
                arcpy.management.CalculateFields(out_poly, 'PYTHON3', 
                                                 [["Mission", "'"+desc.baseName+"'"],
                                                  ["Region", "'"+Region+"'"],
                                                  ["Grid", '!InsideY! + "," + !InsideX!']])
                
            except Exception as e:
                print("!!! Failed !!!")
                failed_list.append(mission)
                failed_count += 1
                #Still working on this section
                

                if os.path.exists(failed_region_path) == False:
                    os.mkdir(failed_region_path)

                if os.path.exists(failed_sensor_path) == False:
                    os.mkdir(failed_sensor_path)
    
                src1 = mission_path
                dst1 = "{}\\{}\\{}\\{}".format(failed_directory_path, region, sensor, mission)
                print(f"--Shutiling {mission} --> {dst1}")
                shutil.move(src1,dst1)
            
print(f"---Failed List: ")
print(*failed_list, sep = '\n')
# Out:
# Reclassifying Sonar Missions
# --SN01483_20210315_ArabianGulf_MST.tif
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [14]:
# Line 22:    reclass = arcpy.sa.Reclassify(in_raster = band_4,
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\sa\Functions.py, in Reclassify:
# Line 7874:  return Wrapper(
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\sa\Utils.py, in swapper:
# Line 55:    result = wrapper(*args, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\sa\Functions.py, in Wrapper:
# Line 7867:  result = arcpy.gp.Reclassify_sa(
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 512:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# Class not registered
# Failed to execute (Reclassify).
#
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Extract by Mask

# %%
arcpy.env.overwrite = True

mission_list = os.listdir(up_sensor_directory_path)

arcpy.env.workspace = region_gdb_path
tiff_list_gdb = arcpy.ListRasters()
reclass_list = arcpy.ListFeatureClasses("p_*", "Polygon") 

#Shutil Variables
src = "{}\\{}".format(up_sensor_directory_path, mission)
dst = "{}\\{}\\{}\\{}\\{}\\{}".format(processed_directory_path, region, sensor, mission_vehicle, mission_year, mission)



for mission in mission_list:
    mission_year = mission[8:12]
    mission_vehicle = mission[0:7]
    mission_name = mission.split(".",1)[0]
    mission_path = "{}\\{}".format(up_sensor_directory_path, mission)
    extension = mission.split(".",1)[1]
    dst = "{}\\{}\\{}\\{}\\{}\\{}".format(processed_directory_path, region, sensor, mission_vehicle, mission_year, mission)
    dste = os.path.exists(dst)
    if extension == 'tif':
        if mission_name not in tiff_list_gdb:
            for reclass in reclass_list:
                reclass_path = os.path.join(region_gdb_path, reclass)
                if reclass[2:] == mission_name:
                    out_ebm = arcpy.sa.ExtractByMask(in_raster=mission_path, in_mask_data = reclass_path)
                    out_ebm.save(os.path.join(region_gdb_path, mission_name))
                    out_ebm.save(dst)
                    
                    #File Checks
                    dste = os.path.exists(dst)
                    srce = os.path.exists(src)
                    if srce == True:
                        if dste == False:
                            print(f"---Shutiling {mission} ---> {dst}")
                            shutil.move(src, dst)
                        else:
                            print(f"---Deleting {src} - Finished Processing")
                            os.remove(src)
        else:
            for reclass in reclass_list:
                reclass_path = os.path.join(relass_gdb_path, reclass)
                if reclass[2:] == mission_name:
                    out_ebm = arcpy.sa.ExtractByMask(in_raster=mission_path, in_mask_data = reclass_path)
                    out_ebm.save(dst) 
                    
                    #File Checks
                    dste = os.path.exists(dst)
                    srce = os.path.exists(src)
                    if srce == True:
                        if dste == False:
                            print(f"---Shutiling {mission} ---> {dst}")
                            shutil.move(src, dst)
                        else:
                            print(f"---Deleting {src} - Finished Processing")
                            os.remove(src)
    else:
        if 'ovr' in extension:
            os.remove(mission_path)
        
        else:
            srce = os.path.exists(src)
            dste = os.path.exists(dst)
            if srce == True:
                if dste == False:
                    print(f"-Shutiling {mission} ----> {dst}")
                    shutil.move(mission_path, dst)


                else:
                    print(f"-Deleting {src} - Non-Tiff")
                    os.remove(mission_path)

print("Done")

# %% [markdown]
# ## Build Pyramids
# This is needed because the new file will not have the background removed unless brand new Pyramids (.ovr) are built. Moving the old pyramid files (.ovr) over will keep the unscrubbed background.

# %%
print(f"Building Pyramids")
for root, dirs, files in os.walk(p_sensor_directory_path):
    for mission in files:
        mission_year = mission[8:12]
        mission_vehicle = mission[0:7]
        extension = mission.split(".", 1)[1]
        mission_name = mission.split(".", 1)[0]
        mission_path = os.path.join(p_year_directory_path, mission)
        if extension == 'tif':
            ovr_path = "{}\{}\{}.tif.ovr".format(p_sensor_directory_path, mission_vehicle, mission_year)
            ovr_check = os.path.exists(ovr_path)
            if ovr_check == False:
                print(f"--{mission_name}")
                arcpy.management.BuildPyramids(mission_path, (-1))

# %% [markdown]
# ## Create and Add Raster Datasets

# %%
arcpy.env.workspace = region_gdb_path

grid = r"Y:\Image_Processing\Image_processing.gdb\EEZ_LatLon_Grids"

raster_list = arcpy.ListRasters("SN*")
poly_list = arcpy.ListFeatureClasses("p_*", "Polygon")
content_list = aprx_map.listLayers("p_*")

# %% [markdown]
# ## Create & Share Map Tile Package for Individual Missions

# %%
print("Creating and Sharing Individual Map Tile Packages")
arcpy.env.workspace = region_gdb_path

for root, dirs, files in os.walk(p_sensor_directory_path):
    for mission in files:
        extension = mission.split(".", 1)[1]
        mission_name = mission.split(".", 1)[0]
        mtp_directory_path = r"Y:\MTP\Individual"
        mtp_directory_list = os.listdir(mtp_directory_path)
        mtp_path = "{}\{}.tpkx".format(mission_name)
        mtp_check = os.path.exists(mtp_path)
        if mtp_check == False:
            
            arcpy.management.CreateMapTilePackage("Sonar Imagery",
                                                  "EXISTING",
                                                  r"Y:\MTP\Individual\{}.tpkx".format(mission_name),
                                                  "MIXED",
                                                  19,
                                                  "https://maps.gvs.nga.mil/arcgis/rest/services/Basemap/NGA_World_Imagery_2D/MapServer",
                                                  '',
                                                  '',
                                                  "DEFAULT",
                                                  75,
                                                  "tpkx",
                                                  0,
                                                  r"in_memory\feature_set1")
            
            arcpy.management.SharePackage(mtp_path,
                                          '',
                                          None,
                                          "Individual Map Tile Package for {}".format(mission_name),
                                          "{}, {}, side scan sonar".format(region, sensor)
                                          '',
                                          "MYGROUPS",
                                          "'Digital Ocean'",
                                          "MYORGANIZATION",
                                          "TRUE",
                                          '')

# %% [markdown]
# # Rename Missions
# Verifies the mission ends with region underscore Sensor

# %%
import arcpy
from sys import argv
import shutil
import os
from os import path
from arcpy import env
from arcpy.sa import *
from datetime import datetime, date, timedelta

sensor_list = ['JSF', 'ATLAS', 'SSAM', 'MST']
region_list = ["ArabianGulf",
               "Baltics",
               "Guam",
               "GulfOman",
               "Juneau",
               "Korea",
               "Kuwait",
               "Massachussetts",
               "PanamaCity",
               "Pendleton",
               'Saipan',
               "SanDiego",
               "SCI",
               "Tasmania",
               "Thailand"]
append_list = []
ext_list = [".prj", ".tfw", ".TFWEx", ".tif"]

##Sets project to Current project; No need to alter
aprx = arcpy.mp.ArcGISProject("CURRENT")
aprx_map = aprx.listMaps("Sonar Imagery")[0]     

#Leave this "True"
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

#Be sure to set appropriately **Change Workspace in mk18Model_UTM11 Function
root_directory_path = r"Y:\TIFFs"
unprocessed_directory_path = r"Y:\TIFFs\Unprocessed_Tiffs"
processed_directory_path = r"Y:\TIFFs\Processed_Tiffs"
region_directory_list = os.listdir(unprocessed_directory_path)
reclass_gdb_path = r"Y:\Image_Processing\Reclass.gdb"
#project_directory_path = r"Y:\TIFFs\Processed_Tiffs\{}\{}".format(project, sensor)
failed_directory_path = r'Y:\Tiffs\Unprocessed_Tiffs\FAILED'
ArcGIS_path = r"Y:\Image_Processing"
utm_directory = r"Y:\Image_Processing\Projection Files\UTM"


#Test Rename to see if it fails due to another mission already has that name, Delete the the duplicate aka the one that has the stripped down name.

def rename():
    for region in region_directory_list:
        if region != 'Thumbs.db':
            sensor_directory_list = os.listdir(os.path.join(unprocessed_directory_path, region))
            for sensor in sensor_directory_list:
                mission_directory_list = os.listdir("{}\\{}\\{}".format(unprocessed_directory_path, region, sensor))
                for mission in mission_directory_list:
                    if mission != 'Thumbs.db':
                        mission_year = mission[8:12]
                        mission_vehicle = mission[0:7]
                        extension = mission.split(".", 1)[1]
                        extension_check = mission[-3:]
                        mission_name = mission.split(".", 1)[0]
                        mission_name = mission_name.replace("-", "_")
                        mission_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
                        if region not in mission:
                            mission_altered = "{}_{}_{}.{}".format(mission_name, region, sensor, extension)
                            mission_altered_name = "{}_{}_{}".format(mission_name, region, sensor)
                            old_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
                            new_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission_altered)
                            mission_path = new_path
                            mission_name = mission_altered_name
                            mission = mission_altered
                            #print(f"Renaming Mission")
                            try:
                                os.rename(old_path, new_path)
                                print(f"^^Renamed {mission}")
                            except Exception as f:
                                #print(f"!!Unable to rename {mission}")
                                print()

# %% [markdown]
# # Full Background Scrubbing Script
# This is the full script

# %%
import arcpy
from sys import argv
import shutil
import os
from os import path
from arcpy import env
from arcpy.sa import *
from datetime import datetime, date, timedelta




'''Exported Mosaics from SonarWiz needs the naming convention: SN0XXXX_YYYYMMDD   anything added after the base name can be left in. The .tif file is only required to begin
with this naming convention.'''



utm_list = ['UTM_Zone_8N', 'UTM_Zone_11N', 'UTM_Zone_16N', "UTM_Zone_19N", 'UTM_Zone_32N', 'UTM_Zone_33N', 'UTM_Zone_39N','UTM_Zone_40N', 'UTM_Zone_55S', 'UTM_Zone_55N', 'Scratch']
sensor_list = ['JSF', 'ATLAS', 'SSAM', 'MST']
region_list = ["ArabianGulf",
               "Baltics",
               "Guam",
               "GulfOman",
               "Juneau",
               "Korea",
               "Kuwait",
               "Massachussetts",
               "PanamaCity",
               "Pendleton",
               'Saipan',
               "SanDiego",
               "SCI",
               "Tasmania",
               "Thailand"]
append_list = []
ext_list = [".prj", ".tfw", ".TFWEx", ".tif"]

##Sets project to Current project; No need to alter
aprx = arcpy.mp.ArcGISProject("CURRENT")
aprx_map = aprx.listMaps("Sonar Imagery")[0]     

#Leave this "True"
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

#Be sure to set appropriately **Change Workspace in mk18Model_UTM11 Function
root_directory_path = r"Y:\TIFFs"
unprocessed_directory_path = r"Y:\TIFFs\Unprocessed_Tiffs"
processed_directory_path = r"Y:\TIFFs\Processed_Tiffs"
region_directory_list = os.listdir(unprocessed_directory_path)
reclass_gdb_path = r"Y:\Image_Processing\Reclass.gdb"
#project_directory_path = r"Y:\TIFFs\Processed_Tiffs\{}\{}".format(project, sensor)
failed_directory_path = r'Y:\Tiffs\Unprocessed_Tiffs\FAILED'
ArcGIS_path = r"Y:\Image_Processing"
utm_directory = r"Y:\Image_Processing\Projection Files\UTM"

'''
def rename():
    for region in region_directory_list:
        if region != 'Thumbs.db':
            sensor_directory_list = os.listdir(os.path.join(unprocessed_directory_path, region))
            for sensor in sensor_directory_list:
                mission_directory_list = os.listdir("{}\\{}\\{}".format(unprocessed_directory_path, region, sensor))
                for mission in mission_directory_list:
                    if mission != 'Thumbs.db':
                        mission_year = mission[8:12]
                        mission_vehicle = mission[0:7]
                        extension = mission.split(".", 1)[1]
                        extension_check = mission[-3:]
                        mission_name = mission.split(".", 1)[0]
                        mission_name = mission_name.replace("-", "_")
                        mission_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
                        if region not in mission:
                            mission_altered = "{}_{}_{}.{}".format(mission_name, region, sensor, extension)
                            mission_altered_name = "{}_{}_{}".format(mission_name, region, sensor)
                            old_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
                            new_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission_altered)
                            mission_path = new_path
                            mission_name = mission_altered_name
                            mission = mission_altered
                            #print(f"Renaming Mission")
                            try:
                                os.rename(old_path, new_path)
                                print(f"^^Renamed {mission}")
                            except Exception as f:
                                #print(f"!!Unable to rename {mission}")
                                print()'''


def gdb_create(region):
    arcpy.env.workspace = ArcGIS_path
    gdb_list = arcpy.ListWorkspaces("*", 'FileGDB')
    gdb_path = "Y:\\Image_Processing\\{}.gdb".format(region)
    if region != "Thumbs.db":
        if gdb_path not in gdb_list:
            arcpy.CreateFileGDB_management(ArcGIS_path, region)
            print(f"-Creating '{region}.gdb'-\n\n")



def create_processed_directories():
    region_directory_path = os.path.join(processed_directory_path, region)
    sensor_directory_path = os.path.join(region_directory_path, sensor)
    vehicle_directory_path = os.path.join(sensor_directory_path, mission_vehicle)
    year_directory_path = os.path.join(vehicle_directory_path, mission_year)
    #Creating Project Directory
    pje = os.path.exists(region_directory_path)
    if pje == False:
        print(f'Creating {region_directory_path}')
        os.mkdir(region_directory_path)

    #Creating Sensor Directory
    sje = os.path.exists(sensor_directory_path)
    if sje == False:
        print(f'Creating {sensor_directory_path}')
        os.mkdir(sensor_directory_path)

    #Creating Vehicle Directory 
    vpe = os.path.exists(vehicle_directory_path)
    if vpe == False:
        print(f"**Creating {vehicle_directory_path}\n")
        os.mkdir(vehicle_directory_path)

    #Creating Year Directory
    ype = os.path.exists(year_directory_path)
    if ype == False:
        print(f"**Creating {year_directory_path}\n")
        os.mkdir(year_directory_path)


def calculate_stats(mission_path):
    aux_file = "{}\\{}\\{}\\{}.tif.aux.xml".format(unprocessed_directory_path, region, sensor, mission_name)
    aux_file_exist = os.path.exists(aux_file)
    xml_file = "{}\\{}\\{}\\{}.tif.xml".format(unprocessed_directory_path, region, sensor, mission_name)
    xml_file_exist = os.path.exists(xml_file)
    if extension == "tif":
        if aux_file_exist == False or xml_file_exist == False:
            print(f"^^Calculating Statistics {mission}")
            arcpy.management.CalculateStatistics(mission_path)
        

def model(mission): 
    s = datetime.now()
    s_str = s.strftime("%H:%M:%S")  
    print(f"+Start Time: {s}")
    #Shutil Variables
    dst = "{}\\{}\\{}\\{}\\{}\\{}".format(processed_directory_path, region, sensor, mission_vehicle, mission_year, mission)
    dste = os.path.exists(dst)

    src = "{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
    srce = os.path.exists(src)
    
    dst_failed = os.path.join(failed_directory_path, mission)
    
    #Sets the default GDB Path
    region_gdb_path = '{}\\{}.gdb'.format(ArcGIS_path, region)

    #Sets the Default GDB to default_gdb_path
    aprx.defaultGeodatabase=region_gdb_path

    #Sets the Environment to the Default GDB
    arcpy.env.workspace = region_gdb_path
    
    arcpy.env.overwriteOutput = True
    #Lists Contents of the Map
    map_contents = aprx_map.listLayers()
    
    if extension == 'tif':
        #ras = arcpy.Raster(mission_path)
        tiff_list_gdb = arcpy.ListRasters()
        
        #If the TIFF is already in the GDB
        if mission_name in tiff_list_gdb:
            print(f"-{mission} Is already in GDB")  
            
            dste = os.path.exists(dst)
            srce = os.path.exists(src)    
            
            if srce == True:
                if dste == False:
                    print(f"--Shutiling {mission} ---> {dst}")
                    shutil.move(src, dst)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")

                else:
                    print(f"--Deleting {src} - Already Been Processed")
                    os.remove(src)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")
                    
        #If the TIFF is not already in the GDB                      
        else:
            print(f"-Processing {mission}")
            #print(f"--{ras.bandCount}")
            if band_num < 4:
                in_raster = mission_path
                
            else:
                band_4 = mission_path + '\\Band_4'
                in_raster = band_4
            
            reclass_field = "Value"
            remap = "0 NODATA; 1 255 2"
            missing_values = "DATA"
            print(f"--Reclassifying {mission}")
            reclass = arcpy.sa.Reclassify(in_raster, reclass_field, remap, missing_values)
            
            print(f"--Saving Reclassified Raster to {region_gdb_path}")
            reclass.save("{}\\r_{}".format(region_gdb_path, mission_name))
            
            '''print(f"--Reclassifying {mission}") #Old 3D Reclassify
            reclass = arcpy.ddd.Reclassify(in_raster, reclass_field, remap, out_raster, missing_values)
            print(f"--Saving Reclassified Polygon to {reclass_gdb_path}")
            #reclass.save("{}\\r_{}".format(reclass_gdb_path, mission_name))'''

            #Extract By Mask
            print(f"--Extracting by Mask {mission_name}")
            out_raster = os.path.join(region_gdb_path, "r_{}".format(mission_name))
            out_ebm = arcpy.sa.ExtractByMask(in_raster=mission_path, in_mask_data = out_raster)
            
            print(f"--Saving Clean Geotiff to {region_gdb_path}")
            out_ebm.save(r"{}\\{}".format(region_gdb_path, mission_name))
            
            print(f"--Saving Clean Geotiff to {dst}")
            out_ebm.save(dst) 
            
            print(f"--Building Pyramids {dst}")
            arcpy.management.BuildPyramids(dst, (-1))
            
            #File Checks
            dste = os.path.exists(dst)
            srce = os.path.exists(src)
            if srce == True:
                if dste == False:
                    print(f"---Shutiling {mission} ---> {dst}")
                    shutil.move(src, dst)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")

                else:
                    print(f"---Deleting {src} - Finished Processing")
                    os.remove(src)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")
                    

    else:
        if 'ovr' in extension:
            print(f"-Deleting ovr File")
            os.remove(mission_path)
            en = datetime.now()
            en_str = en.strftime("%H:%M:%S")
        else:
            if srce == True:
                if dste == False:
                    print(f"-Shutiling {mission} ----> {dst}")
                    shutil.move(src, dst)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")


                else:
                    print(f"-Deleting {src} - Non-Tiff")
                    os.remove(src)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")

    el_time = en - s
    print(f"+Time Elapsed: {el_time}")

    
def failed_dir():
    failed_region_path = os.path.join(failed_directory_path, region)
    failed_sensor_path = os.path.join(failed_region_path, sensor)
    
    if os.path.exists(failed_region_path) == False:
        os.mkdir(failed_region_path)
        
    if os.path.exists(failed_sensor_path) == False:
        os.mkdir(failed_sensor_path)
    


if __name__ == "__main__":
    #Counters 
    count_tot = 0
    count_tif = 0
    count_non_tif = 0
    count_mtp = 0
    failed_list = []
    failed_count = 0
    # mm/dd/y
    start = datetime.now()
    start_time = start.strftime("%H:%M:%S")
    print(f"Start Time: {start_time}")
    #rename()
    #print(f"\n Finished Renaming \n")
    #Iterating through Unprocessed Directory and retrieving Region, Sensor, and Mission
    for region in region_directory_list:
        if region != 'Thumbs.db':
            #print(f"\n {region} \n")
            sensor_directory_list = os.listdir(os.path.join(unprocessed_directory_path, region))
            for sensor in sensor_directory_list:
                #print(f"\n {sensor} \n")
                mission_directory_path = "{}\\{}\\{}".format(unprocessed_directory_path, region, sensor)
                mission_directory_list = os.listdir(mission_directory_path)
                arcpy.env.workspace = mission_directory_path
                for mission in mission_directory_list:
                    #print(f"\n {mission}")
                    if mission != 'Thumbs.db':
                        mission_year = mission[8:12]
                        mission_vehicle = mission[0:7]
                        extension = mission.split(".", 1)[1]
                        extension_check = mission[-3:]
                        mission_name = mission.split(".", 1)[0]
                        mission_path = os.path.join(mission_directory_path, mission)
                        
                        
                        
                        #Adds 1 to the GeoTiff Count
                        if extension == 'tif':
                            desc = arcpy.Describe(mission_path)
                            band_num = desc.bandCount
                            count_tif += 1
                        else:
                            count_non_tif += 1
                            
                        print(f" \n                             **{mission}** \n")
                        #Validating GDB and Creating needed GDB
                        region_gdb_path = "{}\\{}.gdb".format(ArcGIS_path, region)
                        gdb_create(region)
            
                        #Creating Processed Directories
                        create_processed_directories()
                    
                        count_tot += 1
                        #Adding Geotiffs to map
                        calculate_stats(mission_path)
                        
                        #Running Model
                        try:
                            model(mission)
                        except Exception as y:
                            print("!!! Failed !!!")
                            failed_list.append(mission)
                            failed_count += 1
                            #Still working on this section
                            '''failed_dir()
                            src1 = mission_path
                            dst1 = "{}\\{}\\{}\\{}".format(failed_directory_path, region, sensor, mission)
                            print(f"--Shutiling {mission} --> {dst1}")
                            shutil.move(src1,dst1)''' 
                                      

    end = datetime.now()
    end_time = end.strftime("%H:%M:%S")    
    time_elapsed = end - start
    print(f"\n\n All Processing Complete")
    print(f"---Start Time: {start_time}")
    print(f"---End Time: {end_time}")
    print(f"---Time Elapsed: {time_elapsed}")
    print(f"---Tiffs Processed: {count_tif}")
    print(f"---Non-Tiffs Moved: {count_non_tif}")
    print(f"---Total Files: {count_tot}")
    print(f"---MTP Uploaded: {count_mtp}")
    print(f"---Failed Count: {failed_count}")
    print(f"---Failed List: ")
    print(*failed_list, sep = '\n')
# Out:
# Start Time: 16:12:39
#
#  ArabianGulf
#
#
#  ATLAS
#
#
#  JSF
#
#
#  Thumbs.db
#
#  MST
#
#
#  SN01483_20210315_ArabianGulf_MST.tif
#
#                              **SN01483_20210315_ArabianGulf_MST.tif**
#
# +Start Time: 2022-08-08 16:12:40.481389
# -Processing SN01483_20210315_ArabianGulf_MST.tif
# --Reclassifying SN01483_20210315_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01483_20210315_ArabianGulf_MST.tif.aux.xml
#
#                              **SN01483_20210315_ArabianGulf_MST.tif.aux.xml**
#
# +Start Time: 2022-08-08 16:12:47.200438
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\ArabianGulf\MST\SN01483_20210315_ArabianGulf_MST.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.112674
#
#  SN01483_20210315_ArabianGulf_MST.tif.xml
#
#                              **SN01483_20210315_ArabianGulf_MST.tif.xml**
#
# +Start Time: 2022-08-08 16:12:47.386915
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\ArabianGulf\MST\SN01483_20210315_ArabianGulf_MST.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.019946
#
#  SN01483_20210803_ArabianGulf_MST.tif
#
#                              **SN01483_20210803_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01483_20210803_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:13:31.288884
# -Processing SN01483_20210803_ArabianGulf_MST.tif
# --Reclassifying SN01483_20210803_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01484_20210315_ArabianGulf_MST.tif
#
#                              **SN01484_20210315_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01484_20210315_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:13:53.421554
# -Processing SN01484_20210315_ArabianGulf_MST.tif
# --Reclassifying SN01484_20210315_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01484_20210323_ArabianGulf_MST.tif
#
#                              **SN01484_20210323_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01484_20210323_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:14:04.018476
# -Processing SN01484_20210323_ArabianGulf_MST.tif
# --Reclassifying SN01484_20210323_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01484_20210803_ArabianGulf_MST.tif
#
#                              **SN01484_20210803_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01484_20210803_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:14:45.777832
# -Processing SN01484_20210803_ArabianGulf_MST.tif
# --Reclassifying SN01484_20210803_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01485_20210315_ArabianGulf_MST.tif
#
#                              **SN01485_20210315_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01485_20210315_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:15:06.411284
# -Processing SN01485_20210315_ArabianGulf_MST.tif
# --Reclassifying SN01485_20210315_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01556_20210402_DR1_ArabianGulf_MST.tif
#
#                              **SN01556_20210402_DR1_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01556_20210402_DR1_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:15:19.784620
# -Processing SN01556_20210402_DR1_ArabianGulf_MST.tif
# --Reclassifying SN01556_20210402_DR1_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01556_20210621_DR1_ArabianGulf_MST.tif
#
#                              **SN01556_20210621_DR1_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01556_20210621_DR1_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:15:37.463791
# -Processing SN01556_20210621_DR1_ArabianGulf_MST.tif
# --Reclassifying SN01556_20210621_DR1_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01556_20210622_DR2_ArabianGulf_MST.tif
#
#                              **SN01556_20210622_DR2_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01556_20210622_DR2_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:15:54.789806
# -Processing SN01556_20210622_DR2_ArabianGulf_MST.tif
# --Reclassifying SN01556_20210622_DR2_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01556_20210625_DR1_ArabianGulf_MST.tif
#
#                              **SN01556_20210625_DR1_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01556_20210625_DR1_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:16:32.304338
# -Processing SN01556_20210625_DR1_ArabianGulf_MST.tif
# --Reclassifying SN01556_20210625_DR1_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01557_20210402_DR2_ArabianGulf_MST.tif
#
#                              **SN01557_20210402_DR2_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01557_20210402_DR2_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:16:49.732758
# -Processing SN01557_20210402_DR2_ArabianGulf_MST.tif
# --Reclassifying SN01557_20210402_DR2_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  SN01557_20210803_ArabianGulf_MST.tif
#
#                              **SN01557_20210803_ArabianGulf_MST.tif**
#
# ^^Calculating Statistics SN01557_20210803_ArabianGulf_MST.tif
# +Start Time: 2022-08-08 16:17:38.445173
# -Processing SN01557_20210803_ArabianGulf_MST.tif
# --Reclassifying SN01557_20210803_ArabianGulf_MST.tif
# !!! Failed !!!
#
#  Thumbs.db
#
#  SSAM
#
#
#  SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif
#
#                              **SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:18:35.709582
# -Processing SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif
# --Reclassifying SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif
#
#                              **SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:19:34.178641
# -Processing SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif
# --Reclassifying SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif
#
#                              **SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:20:38.454880
# -Processing SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif
# --Reclassifying SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif
#
#                              **SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:21:38.547880
# -Processing SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif
# --Reclassifying SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif
#
#                              **SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:22:16.317189
# -Processing SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif
# --Reclassifying SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif
#
#                              **SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:23:08.545647
# -Processing SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif
# --Reclassifying SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif
#
#                              **SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:24:07.489986
# -Processing SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif
# --Reclassifying SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif
#
#                              **SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:25:08.483828
# -Processing SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif
# --Reclassifying SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  SN06269_20170228_SSAM_ArabianGulf_SSAM.tif
#
#                              **SN06269_20170228_SSAM_ArabianGulf_SSAM.tif**
#
# ^^Calculating Statistics SN06269_20170228_SSAM_ArabianGulf_SSAM.tif
# +Start Time: 2022-08-08 16:25:41.393087
# -Processing SN06269_20170228_SSAM_ArabianGulf_SSAM.tif
# --Reclassifying SN06269_20170228_SSAM_ArabianGulf_SSAM.tif
# !!! Failed !!!
#
#  Baltics
#
#
#  ATLAS
#
#
#  JSF
#
#
#  Thumbs.db
#
#  MST
#  SSAM
#
#
#  Thumbs.db
#
#  Guam
#
#
#  ATLAS
#
#
#  JSF
#
#
#  MST
#
#
#  SSAM
#
#
#  Japan
#
#
#  ATLAS
#
#
#  JSF
#
#
#  MST
#
#
#  SSAM
#
#
#  Juneau
#
#
#  ATLAS
#
#
#  JSF
#
#
#  MST
#
#
#  SSAM
#
#
#  Korea
#
#
#  ATLAS
#
#
#  JSF
#
#
#  MST
#
#
#  SSAM
#
#
#  Kuwait
#
#
#  JSF
#
#
#  MST
#
#
#  Massachusetts
#
#
#  MST
#
#
#  PanamaCity
#
#
#  MST
#
#
#  Pendleton
#
#
#  ATLAS
#
#
#  JSF
#
#
#  MST
#
#
#  SSAM
#
#
#  Saipan
#
#
#  ATLAS
#
#
#  JSF
#
#
#  MST
#
#
#  SSAM
#
#
#  SanDiego
#
#
#  ATLAS
#
#
#  JSF
#
#
#  SN06209_20160217_Grey_SanDiego_JSF.tif
#
#                              **SN06209_20160217_Grey_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06209_20160217_Grey_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:26:40.138232
# -Processing SN06209_20160217_Grey_SanDiego_JSF.tif
# --Reclassifying SN06209_20160217_Grey_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06209_20160217_Grey_SanDiego_JSF.tif.xml
#
#                              **SN06209_20160217_Grey_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-08 16:26:58.729519
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06209_20160217_Grey_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.161879
#
#  SN06209_20160217_LF_Grey_SanDiego_JSF.tif
#
#                              **SN06209_20160217_LF_Grey_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06209_20160217_LF_Grey_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:27:46.538368
# -Processing SN06209_20160217_LF_Grey_SanDiego_JSF.tif
# --Reclassifying SN06209_20160217_LF_Grey_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06209_20160217_LF_Grey_SanDiego_JSF.tif.xml
#
#                              **SN06209_20160217_LF_Grey_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-08 16:28:04.684582
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06209_20160217_LF_Grey_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.125591
#
#  SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif
#
#                              **SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-08 16:28:05.031301
# -Processing SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif
# --Reclassifying SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif.aux.xml
#
#                              **SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-08 16:28:22.537480
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.114693
#
#  SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif.xml
#
#                              **SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-08 16:28:22.719021
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06210_20140605_013604_MISSION_1_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.018927
#
#  SN06210_20160127_IB_ATR_SCM1_SanDiego_JSF.tif
#
#                              **SN06210_20160127_IB_ATR_SCM1_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06210_20160127_IB_ATR_SCM1_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:29:33.123490
# -Processing SN06210_20160127_IB_ATR_SCM1_SanDiego_JSF.tif
# --Reclassifying SN06210_20160127_IB_ATR_SCM1_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120507_SanDiego_JSF.tif
#
#                              **SN06222_20120507_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120507_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:31:01.192724
# -Processing SN06222_20120507_SanDiego_JSF.tif
# --Reclassifying SN06222_20120507_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120508_SanDiego_JSF.tif
#
#                              **SN06222_20120508_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120508_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:32:11.123048
# -Processing SN06222_20120508_SanDiego_JSF.tif
# --Reclassifying SN06222_20120508_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120517_SanDiego_JSF.tif
#
#                              **SN06222_20120517_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120517_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:32:45.031882
# -Processing SN06222_20120517_SanDiego_JSF.tif
# --Reclassifying SN06222_20120517_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120531_2_SanDiego_JSF.tif
#
#                              **SN06222_20120531_2_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120531_2_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:34:01.588886
# -Processing SN06222_20120531_2_SanDiego_JSF.tif
# --Reclassifying SN06222_20120531_2_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120531_SanDiego_JSF.tif
#
#                              **SN06222_20120531_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120531_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:35:16.659041
# -Processing SN06222_20120531_SanDiego_JSF.tif
# --Reclassifying SN06222_20120531_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120809_Juliet_SanDiego_JSF.tif
#
#                              **SN06222_20120809_Juliet_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120809_Juliet_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:36:14.846357
# -Processing SN06222_20120809_Juliet_SanDiego_JSF.tif
# --Reclassifying SN06222_20120809_Juliet_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120809_SanDiego_JSF.tif
#
#                              **SN06222_20120809_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120809_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:37:59.775388
# -Processing SN06222_20120809_SanDiego_JSF.tif
# --Reclassifying SN06222_20120809_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20120924_SanDiego_JSF.tif
#
#                              **SN06222_20120924_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20120924_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:39:04.873358
# -Processing SN06222_20120924_SanDiego_JSF.tif
# --Reclassifying SN06222_20120924_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20121023_SanDiego_JSF.tif
#
#                              **SN06222_20121023_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20121023_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:39:48.041220
# -Processing SN06222_20121023_SanDiego_JSF.tif
# --Reclassifying SN06222_20121023_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20121206_SanDiego_JSF.tif
#
#                              **SN06222_20121206_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20121206_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:40:19.817083
# -Processing SN06222_20121206_SanDiego_JSF.tif
# --Reclassifying SN06222_20121206_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20150708_SanDiego_JSF.tif
#
#                              **SN06222_20150708_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20150708_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:41:36.558206
# -Processing SN06222_20150708_SanDiego_JSF.tif
# --Reclassifying SN06222_20150708_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20150715_VxWorks_Msn1_SanDiego_JSF.tif
#
#                              **SN06222_20150715_VxWorks_Msn1_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20150715_VxWorks_Msn1_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:42:09.275608
# -Processing SN06222_20150715_VxWorks_Msn1_SanDiego_JSF.tif
# --Reclassifying SN06222_20150715_VxWorks_Msn1_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06222_20160803_Collab_Trans_SanDiego_JSF.tif
#
#                              **SN06222_20160803_Collab_Trans_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06222_20160803_Collab_Trans_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:42:42.928697
# -Processing SN06222_20160803_Collab_Trans_SanDiego_JSF.tif
# --Reclassifying SN06222_20160803_Collab_Trans_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20150717_SanDiego_JSF.tif
#
#                              **SN06223_20150717_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20150717_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:44:01.534398
# -Processing SN06223_20150717_SanDiego_JSF.tif
# --Reclassifying SN06223_20150717_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20160419_WK3_FLT_SanDiego_JSF.tif
#
#                              **SN06223_20160419_WK3_FLT_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20160419_WK3_FLT_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:45:35.886663
# -Processing SN06223_20160419_WK3_FLT_SanDiego_JSF.tif
# --Reclassifying SN06223_20160419_WK3_FLT_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20160421_WK3_MS2_SanDiego_JSF.tif
#
#                              **SN06223_20160421_WK3_MS2_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20160421_WK3_MS2_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:47:11.101309
# -Processing SN06223_20160421_WK3_MS2_SanDiego_JSF.tif
# --Reclassifying SN06223_20160421_WK3_MS2_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20160609_SanDiego_JSF.tif
#
#                              **SN06223_20160609_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20160609_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:48:11.816343
# -Processing SN06223_20160609_SanDiego_JSF.tif
# --Reclassifying SN06223_20160609_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20160614_FLTWK3_SanDiego_JSF.tif
#
#                              **SN06223_20160614_FLTWK3_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20160614_FLTWK3_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:49:23.438251
# -Processing SN06223_20160614_FLTWK3_SanDiego_JSF.tif
# --Reclassifying SN06223_20160614_FLTWK3_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20160615_FLTWK3_SanDiego_JSF.tif
#
#                              **SN06223_20160615_FLTWK3_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20160615_FLTWK3_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:50:58.952242
# -Processing SN06223_20160615_FLTWK3_SanDiego_JSF.tif
# --Reclassifying SN06223_20160615_FLTWK3_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06223_20160617_MSNMTR_SanDiego_JSF.tif
#
#                              **SN06223_20160617_MSNMTR_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06223_20160617_MSNMTR_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:51:34.804415
# -Processing SN06223_20160617_MSNMTR_SanDiego_JSF.tif
# --Reclassifying SN06223_20160617_MSNMTR_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20120508_SanDiego_JSF.tif
#
#                              **SN06224_20120508_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20120508_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:52:36.436600
# -Processing SN06224_20120508_SanDiego_JSF.tif
# --Reclassifying SN06224_20120508_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20120608_2_SanDiego_JSF.tif
#
#                              **SN06224_20120608_2_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20120608_2_SanDiego_JSF.tif
# +Start Time: 2022-08-08 16:59:37.671345
# -Processing SN06224_20120608_2_SanDiego_JSF.tif
# --Reclassifying SN06224_20120608_2_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20120608_SanDiego_JSF.tif
#
#                              **SN06224_20120608_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20120608_SanDiego_JSF.tif
# +Start Time: 2022-08-08 17:04:48.541793
# -Processing SN06224_20120608_SanDiego_JSF.tif
# --Reclassifying SN06224_20120608_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20120613_SanDiego_JSF.tif
#
#                              **SN06224_20120613_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20120613_SanDiego_JSF.tif
# +Start Time: 2022-08-08 17:05:38.843775
# -Processing SN06224_20120613_SanDiego_JSF.tif
# --Reclassifying SN06224_20120613_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140710_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140710_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140710_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 17:08:22.364424
# -Processing SN06224_20140710_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140710_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140711_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140711_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140711_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 17:12:52.793468
# -Processing SN06224_20140711_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140711_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140714_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140714_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140714_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 17:34:56.042834
# -Processing SN06224_20140714_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140714_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140716_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140716_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140716_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:08:31.990763
# -Processing SN06224_20140716_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140716_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140721_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140721_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140721_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:22:25.583346
# -Processing SN06224_20140721_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140721_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140722_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140722_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140722_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:24:47.886358
# -Processing SN06224_20140722_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140722_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140723_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140723_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140723_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:27:27.302901
# -Processing SN06224_20140723_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140723_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20140724_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06224_20140724_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20140724_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:35:24.969038
# -Processing SN06224_20140724_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06224_20140724_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06224_20150701_Atlas_Alpha_SanDiego_JSF.tif
#
#                              **SN06224_20150701_Atlas_Alpha_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06224_20150701_Atlas_Alpha_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:42:15.092575
# -Processing SN06224_20150701_Atlas_Alpha_SanDiego_JSF.tif
# --Reclassifying SN06224_20150701_Atlas_Alpha_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20120613_SanDiego_JSF.tif
#
#                              **SN06225_20120613_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20120613_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:44:03.798540
# -Processing SN06225_20120613_SanDiego_JSF.tif
# --Reclassifying SN06225_20120613_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20120614_SanDiego_JSF.tif
#
#                              **SN06225_20120614_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20120614_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:44:40.461631
# -Processing SN06225_20120614_SanDiego_JSF.tif
# --Reclassifying SN06225_20120614_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20130521_GWB_SanDiego_JSF.tif
#
#                              **SN06225_20130521_GWB_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20130521_GWB_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:45:45.456975
# -Processing SN06225_20130521_GWB_SanDiego_JSF.tif
# --Reclassifying SN06225_20130521_GWB_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20130605_GWB_SanDiego_JSF.tif
#
#                              **SN06225_20130605_GWB_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20130605_GWB_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:47:00.160785
# -Processing SN06225_20130605_GWB_SanDiego_JSF.tif
# --Reclassifying SN06225_20130605_GWB_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20140710_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06225_20140710_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20140710_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 18:49:56.334495
# -Processing SN06225_20140710_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06225_20140710_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20140714_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06225_20140714_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20140714_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:08:30.376148
# -Processing SN06225_20140714_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06225_20140714_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20140716_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06225_20140716_RIMPAC_SanDiego_JSF.tif**
# ^^Calculating Statistics SN06225_20140716_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:29:48.039716
# -Processing SN06225_20140716_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06225_20140716_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20140721_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06225_20140721_RIMPAC_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20140721_RIMPAC_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:33:38.067977
# -Processing SN06225_20140721_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06225_20140721_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06225_20150323_INC1_SanDiego_JSF.tif
#
#                              **SN06225_20150323_INC1_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06225_20150323_INC1_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:34:50.866218
# -Processing SN06225_20150323_INC1_SanDiego_JSF.tif
# --Reclassifying SN06225_20150323_INC1_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06255_20140626_SanDiego_JSF.tif
#
#                              **SN06255_20140626_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20140626_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:39:21.268773
# -Processing SN06255_20140626_SanDiego_JSF.tif
# --Reclassifying SN06255_20140626_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06255_20140710_RIMPAC_SanDiego_JSF.tif
#
#                              **SN06255_20140710_RIMPAC_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-08 19:41:38.091727
# -Processing SN06255_20140710_RIMPAC_SanDiego_JSF.tif
# --Reclassifying SN06255_20140710_RIMPAC_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06255_20140710_RIMPAC_SanDiego_JSF.tif.aux.xml
#
#                              **SN06255_20140710_RIMPAC_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-08 19:42:56.104056
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20140710_RIMPAC_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.114656
#
#  SN06255_20140710_RIMPAC_SanDiego_JSF.tif.xml
#
#                              **SN06255_20140710_RIMPAC_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-08 19:42:56.287528
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20140710_RIMPAC_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.018949
#
#  SN06255_20140711_SanDiego_JSF.tif
#
#                              **SN06255_20140711_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-08 19:42:56.492005
# -Processing SN06255_20140711_SanDiego_JSF.tif
# --Reclassifying SN06255_20140711_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06255_20140711_SanDiego_JSF.tif.aux.xml
#
#                              **SN06255_20140711_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-08 19:43:53.371836
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20140711_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.109680
#
#  SN06255_20140711_SanDiego_JSF.tif.xml
#
#                              **SN06255_20140711_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-08 19:43:53.550331
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20140711_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.045878
#
#  SN06255_20160511_Endurance_SanDiego_JSF.tif
#
#                              **SN06255_20160511_Endurance_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20160511_Endurance_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:46:23.237868
# -Processing SN06255_20160511_Endurance_SanDiego_JSF.tif
# --Reclassifying SN06255_20160511_Endurance_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06255_20160615_FLTWK3_SanDiego_JSF.tif
#
#                              **SN06255_20160615_FLTWK3_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20160615_FLTWK3_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:48:13.406132
# -Processing SN06255_20160615_FLTWK3_SanDiego_JSF.tif
# --Reclassifying SN06255_20160615_FLTWK3_SanDiego_JSF.tif
# !!! Failed !!!
#
#  SN06255_20171102_IBF_Collab_SanDiego_JSF.tif
#
#                              **SN06255_20171102_IBF_Collab_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20171102_IBF_Collab_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:48:58.879476
# -Processing SN06255_20171102_IBF_Collab_SanDiego_JSF.tif
# --Reclassifying SN06255_20171102_IBF_Collab_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20171102_IBF_Collab_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2017\SN06255_20171102_IBF_Collab_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2017\SN06255_20171102_IBF_Collab_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20171102_IBF_Collab_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:06:50.082758
#
#  SN06255_20171114_SanDiego_JSF.tif
#
#                              **SN06255_20171114_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20171114_SanDiego_JSF.tif
# +Start Time: 2022-08-08 19:56:11.287477
# -Processing SN06255_20171114_SanDiego_JSF.tif
# --Reclassifying SN06255_20171114_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20171114_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2017\SN06255_20171114_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2017\SN06255_20171114_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20171114_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:04:43.420159
#
#  SN06255_20171130_Tactics_SanDiego_JSF.tif
#
#                              **SN06255_20171130_Tactics_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20171130_Tactics_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:02:05.387125
# -Processing SN06255_20171130_Tactics_SanDiego_JSF.tif
# --Reclassifying SN06255_20171130_Tactics_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20171130_Tactics_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2017\SN06255_20171130_Tactics_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2017\SN06255_20171130_Tactics_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20171130_Tactics_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:18:22.124245
#
#  SN06255_20180215_ATR_SanDiego_JSF.tif
#
#                              **SN06255_20180215_ATR_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20180215_ATR_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:20:31.815711
# -Processing SN06255_20180215_ATR_SanDiego_JSF.tif
# --Reclassifying SN06255_20180215_ATR_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20180215_ATR_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2018\SN06255_20180215_ATR_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2018\SN06255_20180215_ATR_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20180215_ATR_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:01:37.362340
#
#  SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif
#
#                              **SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:22:18.481162
# -Processing SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif
# --Reclassifying SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190211_AMCM_9B_VATR_SCM_aborted_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:25.997022
#
#  SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:25:02.088821
# -Processing SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190213_AMCM_9B_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:03:45.671041
#
#  SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:29:04.206116
# -Processing SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190220_AMCM_5A_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:03:35.086204
#
#  SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:32:56.255083
# -Processing SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190225_AMCM_5B_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:03:37.330559
#
#  SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:36:55.272397
# -Processing SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190226_AMCM_1A_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:04:33.408841
#
#  SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:41:51.629712
# -Processing SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190227_AMCM_1B_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:04:38.916031
#
#  SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif
#
#                              **SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:46:40.257551
# -Processing SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif
# --Reclassifying SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190305_AMCM_6D_VATR_SCM_aborted_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:27.688868
#
#  SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:49:17.053124
# -Processing SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190311_AMCM_10C_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:14.786670
#
#  SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif
#
#                              **SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:51:40.757626
# -Processing SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif
# --Reclassifying SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190312_AMCM_6C_VATR_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:18.006889
#
#  SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif**
# ^^Calculating Statistics SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:54:00.286416
# -Processing SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190313_CHANNEL_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:00:53.985015
#
#  SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:55:05.476214
# -Processing SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190318_AMCM_2A_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:32.287828
#
#  SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 20:57:49.614360
# -Processing SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:38.135016
#
#  SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif.xml
#
#                              **SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-08 21:00:27.832154
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190319_AMCM_3D_VATR_SCM_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.141596
#
#  SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 21:00:32.440798
# -Processing SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190319_MIW_ECHO_VSW_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:01:22.315444
#
#  SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 21:02:07.041033
# -Processing SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190320_AMCM_3C_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:40.790350
#
#  SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 21:05:00.629660
# -Processing SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190325_AMCM_6C_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:48.244579
#
#  SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif
#
#                              **SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif**
#
# ^^Calculating Statistics SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif
# +Start Time: 2022-08-08 21:08:06.674047
# -Processing SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif
# --Reclassifying SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06255\2019\SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06255_20190326_AMCM_2B_VATR_SCM_SanDiego_JSF.tif - Finished Processing
# ...
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.137632
#
#  SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif.ovr
#
#                              **SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif.ovr**
#
# +Start Time: 2022-08-09 21:26:27.215461
# -Deleting ovr File
# +Time Elapsed: 0:00:00.023936
#
#  SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif.xml
#
#                              **SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-09 21:26:27.307215
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.024934
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.prj
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.prj**
#
# +Start Time: 2022-08-09 21:26:27.399967
# -Shutiling SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.prj ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.prj
# +Time Elapsed: 0:00:00.025931
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tfw
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tfw**
#
# +Start Time: 2022-08-09 21:26:27.495711
# -Shutiling SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tfw ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tfw
# +Time Elapsed: 0:00:00.024934
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.TFWEx
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.TFWEx**
#
# +Start Time: 2022-08-09 21:26:27.588463
# -Shutiling SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.TFWEx ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.TFWEx
# +Time Elapsed: 0:00:00.025931
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-09 21:26:27.778953
# -Processing SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif
# --Reclassifying SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:01:11.001798
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.aux.xml
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-09 21:27:38.859567
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.141594
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.ovr
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.ovr**
#
# +Start Time: 2022-08-09 21:27:39.068010
# -Deleting ovr File
# +Time Elapsed: 0:00:00.023908
#
#  SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.xml
#
#                              **SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-09 21:27:39.158739
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.023936
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.prj
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.prj**
#
# +Start Time: 2022-08-09 21:27:39.249496
# -Shutiling SN06320_20200810_RED_GPSFIX_SanDiego_JSF.prj ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.prj
# +Time Elapsed: 0:00:00.026929
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tfw
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tfw**
#
# +Start Time: 2022-08-09 21:27:39.344243
# -Shutiling SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tfw ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tfw
# +Time Elapsed: 0:00:00.024934
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.TFWEx
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.TFWEx**
#
# +Start Time: 2022-08-09 21:27:39.435997
# -Shutiling SN06320_20200810_RED_GPSFIX_SanDiego_JSF.TFWEx ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.TFWEx
# +Time Elapsed: 0:00:00.027926
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-09 21:27:39.675358
# -Processing SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif
# --Reclassifying SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06320_20200810_RED_GPSFIX_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2020\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:24.852813
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.aux.xml
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-09 21:30:04.608971
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.123654
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.ovr
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.ovr**
#
# +Start Time: 2022-08-09 21:30:04.799474
# -Deleting ovr File
# +Time Elapsed: 0:00:00.036900
#
#  SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.xml
#
#                              **SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-09 21:30:04.904166
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20200810_RED_GPSFIX_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.020969
#
#  SN06320_20210303_SanDiego_JSF.prj
#
#                              **SN06320_20210303_SanDiego_JSF.prj**
#
# +Start Time: 2022-08-09 21:30:04.991959
# -Shutiling SN06320_20210303_SanDiego_JSF.prj ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210303_SanDiego_JSF.prj
# +Time Elapsed: 0:00:00.021914
#
#  SN06320_20210303_SanDiego_JSF.tfw
#
#                              **SN06320_20210303_SanDiego_JSF.tfw**
#
# +Start Time: 2022-08-09 21:30:05.080718
# -Shutiling SN06320_20210303_SanDiego_JSF.tfw ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210303_SanDiego_JSF.tfw
# +Time Elapsed: 0:00:00.033884
#
#  SN06320_20210303_SanDiego_JSF.TFWEx
#
#                              **SN06320_20210303_SanDiego_JSF.TFWEx**
#
# +Start Time: 2022-08-09 21:30:05.180451
# -Shutiling SN06320_20210303_SanDiego_JSF.TFWEx ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210303_SanDiego_JSF.TFWEx
# +Time Elapsed: 0:00:00.020920
#
#  SN06320_20210303_SanDiego_JSF.tif
#
#                              **SN06320_20210303_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-09 21:30:05.419813
# -Processing SN06320_20210303_SanDiego_JSF.tif
# --Reclassifying SN06320_20210303_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06320_20210303_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210303_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210303_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210303_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:26.426697
#
#  SN06320_20210303_SanDiego_JSF.tif.aux.xml
#
#                              **SN06320_20210303_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-09 21:32:31.927294
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210303_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.129653
#
#  SN06320_20210303_SanDiego_JSF.tif.ovr
#
#                              **SN06320_20210303_SanDiego_JSF.tif.ovr**
#
# +Start Time: 2022-08-09 21:32:32.123768
# -Deleting ovr File
# +Time Elapsed: 0:00:00.036901
#
#  SN06320_20210303_SanDiego_JSF.tif.xml
#
#                              **SN06320_20210303_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-09 21:32:32.226493
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210303_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.019946
#
#  SN06320_20210310_152943_SanDiego_JSF.prj
#
#                              **SN06320_20210310_152943_SanDiego_JSF.prj**
#
# +Start Time: 2022-08-09 21:32:32.314284
# -Shutiling SN06320_20210310_152943_SanDiego_JSF.prj ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210310_152943_SanDiego_JSF.prj
# +Time Elapsed: 0:00:00.020947
#
#  SN06320_20210310_152943_SanDiego_JSF.tfw
#
#                              **SN06320_20210310_152943_SanDiego_JSF.tfw**
#
# +Start Time: 2022-08-09 21:32:32.403048
# -Shutiling SN06320_20210310_152943_SanDiego_JSF.tfw ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210310_152943_SanDiego_JSF.tfw
# +Time Elapsed: 0:00:00.019919
#
#  SN06320_20210310_152943_SanDiego_JSF.TFWEx
#
#                              **SN06320_20210310_152943_SanDiego_JSF.TFWEx**
#
# +Start Time: 2022-08-09 21:32:32.490786
# -Shutiling SN06320_20210310_152943_SanDiego_JSF.TFWEx ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210310_152943_SanDiego_JSF.TFWEx
# +Time Elapsed: 0:00:00.020944
#
#  SN06320_20210310_152943_SanDiego_JSF.tif
#
#                              **SN06320_20210310_152943_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-09 21:32:32.717205
# -Processing SN06320_20210310_152943_SanDiego_JSF.tif
# --Reclassifying SN06320_20210310_152943_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06320_20210310_152943_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210310_152943_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210310_152943_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210310_152943_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:02:47.183621
#
#  SN06320_20210310_152943_SanDiego_JSF.tif.aux.xml
#
#                              **SN06320_20210310_152943_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-09 21:35:19.983620
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210310_152943_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.133612
#
#  SN06320_20210310_152943_SanDiego_JSF.tif.ovr
#
#                              **SN06320_20210310_152943_SanDiego_JSF.tif.ovr**
#
# +Start Time: 2022-08-09 21:35:20.185051
# -Deleting ovr File
# +Time Elapsed: 0:00:00.020944
#
#  SN06320_20210310_152943_SanDiego_JSF.tif.xml
#
#                              **SN06320_20210310_152943_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-09 21:35:20.271846
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210310_152943_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.020917
#
#  SN06320_20210520_153432_SanDiego_JSF.prj
#
#                              **SN06320_20210520_153432_SanDiego_JSF.prj**
#
# +Start Time: 2022-08-09 21:35:20.359585
# -Shutiling SN06320_20210520_153432_SanDiego_JSF.prj ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210520_153432_SanDiego_JSF.prj
# +Time Elapsed: 0:00:00.020943
#
#  SN06320_20210520_153432_SanDiego_JSF.tfw
#
#                              **SN06320_20210520_153432_SanDiego_JSF.tfw**
#
# +Start Time: 2022-08-09 21:35:20.447350
# -Shutiling SN06320_20210520_153432_SanDiego_JSF.tfw ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210520_153432_SanDiego_JSF.tfw
# +Time Elapsed: 0:00:00.021941
#
#  SN06320_20210520_153432_SanDiego_JSF.TFWEx
#
#                              **SN06320_20210520_153432_SanDiego_JSF.TFWEx**
#
# +Start Time: 2022-08-09 21:35:20.536112
# -Shutiling SN06320_20210520_153432_SanDiego_JSF.TFWEx ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210520_153432_SanDiego_JSF.TFWEx
# +Time Elapsed: 0:00:00.021941
#
#  SN06320_20210520_153432_SanDiego_JSF.tif
#
#                              **SN06320_20210520_153432_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-09 21:35:20.767492
# -Processing SN06320_20210520_153432_SanDiego_JSF.tif
# --Reclassifying SN06320_20210520_153432_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06320_20210520_153432_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210520_153432_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210520_153432_SanDiego_JSF.tif
# ---Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210520_153432_SanDiego_JSF.tif - Finished Processing
# +Time Elapsed: 0:04:59.533707
#
#  SN06320_20210520_153432_SanDiego_JSF.tif.aux.xml
#
#                              **SN06320_20210520_153432_SanDiego_JSF.tif.aux.xml**
#
# +Start Time: 2022-08-09 21:40:20.382966
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210520_153432_SanDiego_JSF.tif.aux.xml - Non-Tiff
# +Time Elapsed: 0:00:00.136619
#
#  SN06320_20210520_153432_SanDiego_JSF.tif.ovr
#
#                              **SN06320_20210520_153432_SanDiego_JSF.tif.ovr**
#
# +Start Time: 2022-08-09 21:40:20.586438
# -Deleting ovr File
# +Time Elapsed: 0:00:00.036897
#
#  SN06320_20210520_153432_SanDiego_JSF.tif.xml
#
#                              **SN06320_20210520_153432_SanDiego_JSF.tif.xml**
#
# +Start Time: 2022-08-09 21:40:20.690129
# -Deleting Y:\TIFFs\Unprocessed_Tiffs\SanDiego\JSF\SN06320_20210520_153432_SanDiego_JSF.tif.xml - Non-Tiff
# +Time Elapsed: 0:00:00.019946
#
#  SN06320_20210819_151307_SanDiego_JSF.prj
#
#                              **SN06320_20210819_151307_SanDiego_JSF.prj**
#
# +Start Time: 2022-08-09 21:40:20.775934
# -Shutiling SN06320_20210819_151307_SanDiego_JSF.prj ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210819_151307_SanDiego_JSF.prj
# +Time Elapsed: 0:00:00.021932
#
#  SN06320_20210819_151307_SanDiego_JSF.tfw
#
#                              **SN06320_20210819_151307_SanDiego_JSF.tfw**
#
# +Start Time: 2022-08-09 21:40:20.864693
# -Shutiling SN06320_20210819_151307_SanDiego_JSF.tfw ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210819_151307_SanDiego_JSF.tfw
# +Time Elapsed: 0:00:00.020913
#
#  SN06320_20210819_151307_SanDiego_JSF.TFWEx
#
#                              **SN06320_20210819_151307_SanDiego_JSF.TFWEx**
# +Start Time: 2022-08-09 21:40:20.949435
# -Shutiling SN06320_20210819_151307_SanDiego_JSF.TFWEx ----> Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210819_151307_SanDiego_JSF.TFWEx
# +Time Elapsed: 0:00:00.019948
#
#  SN06320_20210819_151307_SanDiego_JSF.tif
#
#                              **SN06320_20210819_151307_SanDiego_JSF.tif**
#
# +Start Time: 2022-08-09 21:40:21.181814
# -Processing SN06320_20210819_151307_SanDiego_JSF.tif
# --Reclassifying SN06320_20210819_151307_SanDiego_JSF.tif
# --Saving Reclassified Polygon to Y:\Image_Processing\Reclass.gdb
# --Extracting by Mask SN06320_20210819_151307_SanDiego_JSF
# --Saving Clean Geotiff to Y:\Image_Processing\SanDiego.gdb
# --Saving Clean Geotiff to Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210819_151307_SanDiego_JSF.tif
# --Building Pyramids Y:\TIFFs\Processed_Tiffs\SanDiego\JSF\SN06320\2021\SN06320_20210819_151307_SanDiego_JSF.tif

# %% [markdown]
# # Create and Publish Map Tile Packages for Individual Missions to NGA Portal

# %%
import os
import arcpy

#Paths
ArcGIS_path = r"Y:\Image_Processing" 
mtp_directory_path = r"Y:\MTP\Individual"

#Environment
arcpy.env.workspace = ArcGIS_path

#Lists
gdb_list = arcpy.ListWorkspaces("*", "FileGDB")
sensor_list = ["SSAM", "ATLAS", "MST", "JSF"]
region_list = ["ArabianGulf",
               "Baltics",
               "Guam",
               "GulfOman",
               "Juneau",
               "Korea",
               "Massachusetts",
               "PanamaCity",
               "Pendleton",
               'Saipan',
               "SanDiego",
               "SCI",
               "Tasmania",
               "Thailand"
]

#Map
aprx = arcpy.mp.ArcGISProject("CURRENT")
m = aprx.listMaps("Publish")[0]
map_name = m.name
print(f"---Map: {map_name}")

def verify_directories():
    for region in region_list:
        region_directory_path = os.path.join(mtp_directory_path, region)
        if os.path.exists(region_directory_path) == False:
            os.mkdir(region_directory_path)
            for sensor in sensor_list:
                sensor_directory_path = os.path.join(region_directory_path, sensor)
                if os.path.exists(sensor_directory_path) == False:
                    os.mkdir(sensor_directory_path)
                    
            


def mtp():
    #Set Active GDB
    for gdb in gdb_list:
        desc = arcpy.Describe(gdb)
        if desc.baseName in region_list:
            region = desc.baseName
            print(f"---GDB: {gdb}\n")
            aprx.defaultGeodatabase= gdb    
            arcpy.env.workspace = gdb

            raster_list = arcpy.ListRasters("*")
            for raster in raster_list:
                sensor = raster.split("_")[-1]
                mtp_file = "{}\{}\{}\{}.tpkx".format(mtp_directory_path, region, sensor, raster)
                mtp_check = os.path.exists(mtp_file)
                summary = "{} individual mission".format(raster)
                tags = "{},{}, MTP, Individual".format(region, sensor)
                if mtp_check == False:
                    print(f"*** {raster} ***")
                    raster_path = os.path.join(gdb, raster)
                    print(f"--Adding layer to Map")
                    m.addDataFromPath(raster_path)
                    print(f"--Creating Map Tile Package")
                    arcpy.management.CreateMapTilePackage(m,
                                                          "EXISTING",
                                                          mtp_file,
                                                          "MIXED",
                                                          19, 
                                                          "https://maps.gvs.nga.mil/arcgis/rest/services/Basemap/NGA_World_Imagery_2D/MapServer",
                                                          summary,
                                                          tags,
                                                          "DEFAULT",
                                                          75,
                                                          "tpkx",
                                                          0,
                                                          "")
                    print(f"--Uploading and Publishing Map Tile Package")
                    results = arcpy.management.SharePackage(mtp_file,
                                                            "",
                                                            "",
                                                            summary,
                                                            tags,
                                                            "Orca Maritime - Ted Smith",
                                                            "MYGROUPS",
                                                            "Digital Ocean",
                                                            "EVERYBODY",
                                                            "TRUE",
                                                            "Map Tile Package - Individual")

                    print(results)
                    print("--Removing Mission from 'Publish' Map\n")
                    #arcpy.SetParameterAsText()
                    lyr_list = m.listLayers()
                    for lyr in lyr_list:
                        m.removeLayer(lyr)


if __name__ == "__main__":
    verify_directories()
    mtp()
    print("\nDone")
# Out:
# ---Map: Publish
# ---GDB: Y:\Image_Processing\ArabianGulf.gdb
#
# *** SN06308_20200311_3_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06308_20200311_2_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06308_20200311_1_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06285_20170423_SSAM_ArabianGulf_SSAM ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06269_20170228_SSAM_ArabianGulf_H5 ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150329_FPO3_DR4_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150328_DR4_BB19_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150327_A1213_DR4_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150326_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150128_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150121_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150114_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20150107_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06254_20131209_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06253_20150330_DR4_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06253_20150329_FPO3_DR3_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# true
# --Removing Mission from 'Publish' Map
#
# *** SN06253_20150328_DR3_BB1_9_ArabianGulf_JSF ***
# --Adding layer to Map
# --Creating Map Tile Package
# --Uploading and Publishing Map Tile Package
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [18]:
# Line 108:   mtp()
#
# In  [18]:
# Line 86:    results = arcpy.management.SharePackage(mtp_file,
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py, in SharePackage:
# Line 12777: raise e
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py, in SharePackage:
# Line 12774: retval = convertArcObjectToPythonObject(gp.SharePackage_management(*gp_fixargs((in_package, username, password, summary, tags, credits, public, groups, organization, publish_web_layer, portal_folder), True)))
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 512:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# Failed to execute (SharePackage).
#
# ---------------------------------------------------------------------------

# %% [markdown]
# # Create and Publish Map Image Layers for Individual Missions to NGA Portal

# %%
import os
import arcpy

#Paths
ArcGIS_path = r"Y:\Image_Processing" 
sd_directory_path = r"Y:\SD_Draft\Individual"

#Environment
arcpy.env.workspace = ArcGIS_path

#Lists
gdb_list = arcpy.ListWorkspaces("*", "FileGDB")
sensor_list = ["SSAM", "ATLAS", "MST", "JSF"]
region_list = ["ArabianGulf",
               #"Baltics",
               #"Guam",
               #"GulfOman",
               "Juneau",
               "Korea",
               "Massachusetts",
               "PanamaCity",
               "Pendleton",
               'Saipan',
               "SanDiego",
               "SCI",
               "Tasmania",
               "Thailand"
]

#Map
aprx = arcpy.mp.ArcGISProject("CURRENT")
m = aprx.listMaps("Publish")[0]
map_name = m.name
print(f"---Map: {map_name}")

def verify_directories():
    for region in region_list:
        region_directory_path = os.path.join(sd_directory_path, region)
        if os.path.exists(region_directory_path) == False:
            os.mkdir(region_directory_path)
            for sensor in sensor_list:
                sensor_directory_path = os.path.join(region_directory_path, sensor)
                if os.path.exists(sensor_directory_path) == False:
                    os.mkdir(sensor_directory_path)
def mil():
    for gdb in gdb_list:
            desc = arcpy.Describe(gdb)
            if desc.baseName in region_list:
                region = desc.baseName
                print(f"---GDB: {gdb}\n")
                aprx.defaultGeodatabase= gdb    
                arcpy.env.workspace = gdb
                raster_list = arcpy.ListRasters("SN06232_20150124*")
                #print(f"Raster List--{raster_list}")
                for raster in raster_list:
                    sensor = raster.split("_")[-1]
                    print(f"Raster--{raster}")
                    # Set Output File Names
                    service_name = raster
                    sddraft_filename = service_name + ".sddraft"
                    sddraft_output_filename = "{}\{}\{}\{}".format(sd_directory_path, region, sensor, sddraft_filename)
                    sd_filename = service_name + ".sd"
                    sd_output_filename =  "{}\{}\{}\{}".format(sd_directory_path, region, sensor, sd_filename)
                    raster_path = os.path.join(gdb, raster)

                    # Reference map to Publish
                    l = m.listLayers()
                    sd_check = os.path.exists(sd_output_filename)
                    print(f"SD Path Check--{sd_check}")
                    if sd_check == False:
                        print(f"Adding {raster} to Map")
                        m.addDataFromPath(raster_path)
                        l = m.listLayers()

                        # Create MapImageSharingDraft and set metadata, portal folder, and server folder properties
                        server_type = "FEDERATED_SERVER"
                        federated_server_url = "https://hostedservices.geo.nga.mil/hosted1"
                        sddraft = m.getWebLayerSharingDraft(server_type, "MAP_IMAGE", service_name)
                        sddraft.federatedServerUrl = federated_server_url
                        sddraft.credits = "Orca Maritime"
                        sddraft.description = "{} Mission Sonar Data".format(service_name)
                        sddraft.summary = "This is summary"
                        sddraft.tags = "sonar, {}, {}".format(region, sensor)
                        print(f"Tags--{sddraft.tags}")
                        sddraft.useLimitations = ""
                        sddraft.portalFolder = "Map Image Layers - Individual"
                        sddraft.serverFolder = ""

                        # Create Service Definition Draft file
                        print("Creating SD Draft File")
                        sddraft.exportToSDDraft(sddraft_output_filename)
                        lyr_list = m.listLayers()
                        # Stage Service
                        print("Start Staging")
                        arcpy.StageService_server(sddraft_output_filename, sd_output_filename)

                        # Share to portal
                        print("Start Uploading")
                        upload = arcpy.UploadServiceDefinition_server(sd_output_filename, federated_server_url)
                        print("Finish Publishing")
                        result = upload.getMapImageURL()
                        print(f"Item ID -- {result}")
                        #print(f"Feature Service REST URL--{upload.out_featureServiceURL}")
                        #print(f"Map Service REST URL--{upload.out_mapServiceURL}")
                        print("Removing Mission from 'Publish' Map\n")
                        lyr_list = m.listLayers()
                        for lyr in lyr_list:
                            m.removeLayer(lyr)
                    

if __name__ == "__main__":
    verify_directories()
    mil()
    print("\nDone")
# Out:
# ---Map: Publish
# ---GDB: Y:\Image_Processing\ArabianGulf.gdb
#
# Raster--SN06232_20150124_2_ArabianGulf_JSF
# SD Path Check--False
# Adding SN06232_20150124_2_ArabianGulf_JSF to Map
# Tags--sonar, ArabianGulf, JSF
# Creating SD Draft File
# Start Staging
# Start Uploading
# Finish Publishing
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# In  [34]:
# Line 113:   mil()
#
# In  [34]:
# Line 101:   result = upload.getMapImageURL()
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\arcobjects\arcobjects.py, in getMapImageURL:
# Line 2483:  return convertArcObjectToPythonObject(self._arc_object.GetMapImageURL(*gp_fixargs(args)))
#
# RuntimeError: ResultObject: Error in getting map image URL
# ---------------------------------------------------------------------------

# %% [markdown]
# # Create and Publish Map Image Layers for Multiple Missions to NGA Portal

# %% [markdown]
# # Creating and Adding Raster Datasets to Mosaic Datasets
# This is based off of the old script. This hasn't been adjusted to incorporate sorting based on 1-minute grid.

# %%
aprx = arcpy.mp.ArcGISProject("CURRENT")
aprx_map = aprx.listMaps("Sonar Imagery")[0]     
ArcGIS_path = r"Y:\Image_Processing"

region_list = ["ArabianGulf",
               "Baltics",
               "Guam",
               "GulfOman",
               "Juneau",
               "Korea",
               "Kuwait",
               "Massachussetts",
               "PanamaCity",
               "Pendleton",
               'Saipan',
               "SanDiego",
               "SCI",
               "Tasmania",
               "Thailand"]



def add_reclass():
    reclass_gdb_path = os.path.join(ArcGIS_path, "Reclass.gdb")
    arcpy.env.workspace = reclass_gdb_path
    reclass_list = arcpy.ListRasters()
    for reclass in reclass_list:
        aprx_map.addDataFromPath(os.path.join(reclass_gdb_path, reclass))
        

def sonar_list(gdb):
    gdb_path = os.path.join(ArcGIS_path, gdb)
    arcpy.env.workspace = gdb_path
    sonar_list = arcpy.ListRasters()
    return sonar_list

def gdb_list():
    arcpy.env.workspace = ArcGIS_path
    gdb_list = arcpy.ListWorkspaces(*, "FileGDB")
    return gdb_list

def reclass_polygon(gdb):
    gdb_path = os.path.join(ArcGIS_path, gdb)
    arcpy.env.workspace = gdb_path
    reclass_list = arcpy.ListRasters("r_*)                              
    for r in reclass_list:
        baseName = r.split("_", 1)[1]
        baseName = "p_{}".format(baseName)
        out_poly = os.path.join(region_gdb_path, baseName)
        arcpy.env.addOutputsToMap = True
        arcpy.conversion.RasterToPolygon(r, out_poly, "SIMPLIFY", "Value", "MULTIPLE_OUTER_PART", None)

def spatial_join():
    lyr_list = aprx_map.listLayers("r_*")
    for lyr in lyr_list:
    arcpy.analysis.SpatialJoin(target_features = grid,
                               join_features = reclass,
                               out_feature_class = joined_reclass,
                               join_operation = "ONE-TO-MANY", 
                               join_type = 'KEEP_ALL',
                               field_mapping = None,
                               match_option = 'HAVE_THEIR_CENTER_IN',
                               search_radius = None,
                               distance_field_name = None)
                                     
                                     
    
    


add_reclass()
for gdb in gdb_list():
    if gdb in region_list:
        desc = arcpy.Describe(gdb)
        add_reclass(gdb)
        spatial_join()
        

            
        
        
            
                                         
            
            
        
            
        
        
        
        
        
        
        






coor_grid_path = os.path.join(ArcGIS_path, "Default.gdb") + "Coor_Grid"

arcpy.management.SelectLayerByLocation(reclass_poly_path, "WITHIN")


# Get

# %%
###### Script for Mosaic Dataset 

region_list = ["ArabianGulf",
               "Baltics",
               "Guam",
               "GulfOman",
               "Juneau",
               "Korea",
               "Kuwait",
               "Massachussetts",
               "PanamaCity",
               "Pendleton",
               'Saipan',
               "SanDiego",
               "SCI",
               "Tasmania",
               "Thailand"]

ArabianGulf =
Baltics = 
Guam = ["14N 144E", "14N 145E"]
Juneau = ["58N 134W","58N 135W", "59N 134W","59N 135W", "59N 136W", "60N 136W", ""]
Korea = 
Kuwait = 
Massachussetts = ["42N 71W", "42N 72W", "43N 71W"]
PanamaCity = ["31N 86W", "30N 86W", "30N 87W", "31N 87W"]
Pendleton = ["34N 118W"]
Saipan = 
SanDiego = ["33N 118W"]
SCI = ["33N 119W", "34N 119W"]
Tasmania = ['43S 145E','43S 146E','43S 147E','43S 148E','42S 144E','42S 145E','42S 147E',42S 148E,41S 144E,41S 145E,41S 146E,41S 147E,41S 148E,'40S 144E','40S 145E','40S 146E','40S 147E','40S 148E']
Thailand = 



md_list = []

wgs84 = 
def verify_mosaic_dataset():
    print('\n Creating Project Mosaic Dataset \n')
    arcpy.env.workspace = region_gdb_path
    dataset_list = arcpy.ListDatasets('*', 'Mosaic')
    for md in 
    fc = world_grid
    field = "block"
    arcpy.env.Overwrite = False
    with arcpy.da.SearchCursor(fc, field):
        if field in md_list:
            try:
                print(f"Creating {project} Mosaic Dataset")
                arcpy.management.CreateMosaicDataset(region_gdb_path, project, prj, 4, "32_BIT_FLOAT")
                
                
    if project in dataset_list:
        print(f"{project} Mosaic Dataset Has Already Been Created")
    else:
        print(f"Creating {project} Mosaic Dataset")
        arcpy.management.CreateMosaicDataset(default_gdb_path, project, prj, 4, "32_BIT_FLOAT")


def populate_md():
    arcpy.env.workspace = default_gdb_path
    dataset_list = arcpy.ListDatasets("SN*")
    for r in dataset_list:
        #r_split = r.split('_')[-1]
        if r in append_list:
            '''sr  = arcpy.Describe(raster).spatialReference
            sr_name = sr.name
            sr_split = sr_name.split'''
            #input_path = os.path.join(default_gdb_path, r)  
            print(f"Adding {r} to {project} Mosaic Dataset")
            mdname = os.path.join(default_gdb_path, project)
            rastype = "Raster Dataset"
            inpath = os.path.join(default_gdb_path, r)
            updatecs = "UPDATE_CELL_SIZES"
            updatebnd = "UPDATE_BOUNDARY"
            updateovr = "NO_OVERVIEWS"
            maxlevel = None
            maxcs = "0"
            maxdim = "1500"
            spatialref = prj
            inputdatafilter = ""
            subfolder = "SUBFOLDERS"
            duplicate = "EXCLUDE_DUPLICATES"
            buildpy = "BUILD_PYRAMIDS"
            calcstats = "CALCULATE_STATISTICS"
            buildthumb = "NO_THUMBNAILS"
            comments = "{}".format(r)
            forcesr = 'FORCE_SPATIAL_REFERENCE'
            estimatestats = "ESTIMATE_STATISTICS"
            auxilaryinput = None
            enablepixcache = "NO_PIXEL_CACHE"
            arcpy.AddRastersToMosaicDataset_management(
             mdname,  rastype, inpath, updatecs, updatebnd, updateovr,
             maxlevel, maxcs, maxdim, spatialref, inputdatafilter,
             subfolder, duplicate, buildpy, calcstats, 
             buildthumb, comments, forcesr, estimatestats,
             auxilaryinput, enablepixcache)
            

                                
                                
def add_mosaicdataset():
    arcpy.env.workspace = default_gdb_path
    md_list = arcpy.ListDatasets("*", "Mosaic")
    md_list_map = aprx_map.listLayers()
    val_list = []
    for md in md_list:
        for m in md_list_map:
            val_list.append(m)
            if md in val_list:
                print(f"{md} Has Already Been Added to Map")
            else:
                path = os.path.join(default_gdb_path, md)
                aprx_map.addDataFromPath(path)
                    

def calculate_fields():
    arcpy.env.workspace = default_gdb_path
    md_list = arcpy.ListDatasets("*", "Mosaic")
    field_value = ['Year', 'Vessel Number']
    for md in md_list:
        if md == project:
            md_f = md + "\\Footprint"
            for f in field_value:
                field_list = arcpy.ListFields(md_f)
                if f in field_list:
                    print(f"{f} field has already been created")
                    arcpy.management.CalculateFields(md_f, 'PYTHON3',
                                              [["Year", '!Name![8:12]'],
                                         ["VesselNum", '!Name![3:7]']])
                else:
                    arcpy.management.AddFields(md_f,
                                       [["Year", "TEXT"],
                                        ["VesselNum", "TEXT", "Vessel Number"]])
                    print("'Year' & 'Vessel Number' Fields Added")
                    arcpy.management.CalculateFields(md_f, 'PYTHON3',
                                              [["Year", '!Name![8:12]'],
                                         ["VesselNum", '!Name![3:7]']])
                    print("'Year' & 'Vessel Number' Fields Calculated")

            print("Calculating 'MaxPs' field")
            arcpy.management.CalculateField(md_f, field="MaxPs", expression="2000", expression_type="PYTHON3", code_block="", field_type = "TEXT", enforce_domains="NO_ENFORCE_DOMAINS")[0]        

def build_footprints():
    arcpy.env.workspace = default_gdb_path
    md_list = arcpy.ListDatasets("*", "Mosaic")
    for p in md_list:
        in_p = os.path.join(default_gdb_path, p)
        approx_num_vertices = -1
        print("Building Footprints")
        arcpy.management.BuildFootprints(in_p, approx_num_vertices=-1)
                                   
    print("All Footprints have been built")   
    
    
    
 #Adds the newly processed Geotiffs to the appropriate Mosaic Dataset based on Project
    print(append_list)
    populate_md()
    
    #Adds the mosaic datase to the current map if not already added                            
    #add_mosaicdataset()
                             
    #Creates and Calculates 'MaxPs', 'Year', 'Vessel Number' Fields                           
    calculate_fields()                      
    
    #Builds Footprints
    build_footprints()

# %% [markdown]
# # Background Scrubber: D-Drive a.k.a Olivia's Machine
# Use this script when running the process directly off of Olivia's Machine.

# %%
import arcpy
from sys import argv
import shutil
import os
from os import path
from arcpy import env
from arcpy.sa import *
from datetime import datetime, date, timedelta



##Coordinate System Bank
#8N - Juneau, AK
#11N - San Diego/SCI/Pendleton
#16N - Panama City, FL area
#19N - Providence, RI area
#32N - Denmark/Central Germany(Hamburg, Hanover)/Norway 
#33N - East Germany(Berlin)/West Poland/Sweden
#39N - Arabian Gulf
#40N - Gulf of Oman* Check the naming convention
#55S - Tasmania, Au
#55N - Guam

'''Exported Mosaics from SonarWiz needs the naming convention: SN0XXXX_YYYYMMDD   anything added after the base name can be left in. The .tif file is only required to begin
with this naming convention.'''



utm_list = ['UTM_Zone_8N', 'UTM_Zone_11N', 'UTM_Zone_16N', "UTM_Zone_19N", 'UTM_Zone_32N', 'UTM_Zone_33N', 'UTM_Zone_39N','UTM_Zone_40N', 'UTM_Zone_55S', 'UTM_Zone_55N', 'Scratch']
sensor_list = ['JSF', 'ATLAS', 'SSAM', 'MST']
region_list = ["Korea", "Thailand",'Saipan', "Juneau","Baltics", "Pendleton", "SCI", "SanDiego", "ArabianGulf", "Guam", "Tasmania", "PanamaCity", "Providence", "GulfOman"]
append_list = []
ext_list = [".prj", ".tfw", ".TFWEx", ".tif"]




                 
##Used for Mosaic Datasets
#utm_long = "WGS_1984_UTM_Zone_{}".format(utm)
#utm_ext = spatial_ref + '.prj'
#prj_file_path = os.path.join(utm_directory, utm_ext)
#with open(prj_file_path) as r:
#    prj = r.read()
#    #print(prj)      





##Sets project to Current project; No need to alter
aprx = arcpy.mp.ArcGISProject("CURRENT")
aprx_map = aprx.listMaps("Sonar Imagery")[0]     

#Leave this "True"
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

#Be sure to set appropriately **Change Workspace in mk18Model_UTM11 Function
root_directory_path = r"D:\Image_Processing\TIFFs"
unprocessed_directory_path = r"D:\Image_Processing\TIFFs\Unprocessed_Tiffs"
processed_directory_path = r"D:\Image_Processing\TIFFs\Processed_Tiffs"
region_directory_list = os.listdir(unprocessed_directory_path)

#project_directory_path = r"Y:\TIFFs\Processed_Tiffs\{}\{}".format(project, sensor)
failed_directory_path = r'D:\Image_Processing\TIFFs\FAILED'
ArcGIS_path = r"D:\Image_Processing\Image_Processing"
utm_directory = r"D:\Image_Processing\Image_Processing\Projection Files\UTM"




   
def gdb_create(region):
    arcpy.env.workspace = ArcGIS_path
    gdb_list = arcpy.ListWorkspaces("*", 'FileGDB')
    gdb_path = "D:\\Image_Processing\\Image_processing\\{}.gdb".format(region)
    if region != "Thumbs.db":
        if gdb_path not in gdb_list:
            arcpy.CreateFileGDB_management(ArcGIS_path, region)
            print(f"-Creating '{region}.gdb'-\n\n")



def create_processed_directories():
    region_directory_path = os.path.join(processed_directory_path, region)
    sensor_directory_path = os.path.join(region_directory_path, sensor)
    vehicle_directory_path = os.path.join(sensor_directory_path, mission_vehicle)
    year_directory_path = os.path.join(vehicle_directory_path, mission_year)
    #Creating Project Directory
    pje = os.path.exists(region_directory_path)
    if pje == False:
        print(f'Creating {region_directory_path}')
        os.mkdir(region_directory_path)

    #Creating Sensor Directory
    sje = os.path.exists(sensor_directory_path)
    if sje == False:
        print(f'Creating {sensor_directory_path}')
        os.mkdir(sensor_directory_path)

    #Creating Vehicle Directory 
    vpe = os.path.exists(vehicle_directory_path)
    if vpe == False:
        print(f"**Creating {vehicle_directory_path}\n")
        os.mkdir(vehicle_directory_path)

    #Creating Year Directory
    ype = os.path.exists(year_directory_path)
    if ype == False:
        print(f"**Creating {year_directory_path}\n")
        os.mkdir(year_directory_path)



def model(mission): 
    


    s = datetime.now()
    s_str = s.strftime("%H:%M:%S")  
    print(f"+Start Time: {s}")
    #Shutil Variables
    dst = "{}\{}\{}\{}\{}\{}".format(processed_directory_path, region, sensor, mission_vehicle, mission_year, mission)
    dste = os.path.exists(dst)

    src = "{}\{}\{}\{}".format(unprocessed_directory_path, region, sensor, mission)
    srce = os.path.exists(src)
    
    dst_failed = os.path.join(failed_directory_path, mission)
    
    #Sets the default GDB Path
    default_gdb_path = '{}\{}.gdb'.format(ArcGIS_path, region)

    #Sets the Default GDB to default_gdb_path
    aprx.defaultGeodatabase=default_gdb_path

    #Sets the Environment to the Default GDB
    arcpy.env.workspace = default_gdb_path
    
    #Lists Contents of the Map
    map_contents = aprx_map.listLayers()
    
    if extension == 'tif':
        #utm_zone = spatial_reference[9:]

        band_4 = mission + '\\Band_4'
        tiff_list_gdb = arcpy.ListRasters()

        #If the TIFF is already in the GDB
        if mission_name in tiff_list_gdb:
            
            print(f"-{mission} Has already been Processed\n")      
            if srce == True:
                if dste == False:
                    print(f"--Shutiling {mission} ---> {dst}\n")
                    shutil.move(src, dst)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")

                else:
                    print(f"--Deleting {src} - Already Been Processed\n")
                    os.remove(src)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")
                    
        #If the TIFF is not already in the GDB                      
        else:
            
            print(f"-Processing {mission}")
            
            #Reclassify Band_4
            
            print(f"--Reclassifying {mission}")
            arcpy.ddd.Reclassify(in_raster = mission_path,
                                reclass_field = "Value",
                                remap = "0 NODATA;0.10 255 2",
                                out_raster = os.path.join(default_gdb_path, "reclass"),
                                missing_values = "DATA")

            #Extract By Mask
            print(f"--Extracting by Mask {mission_name}")
            out_raster = os.path.join(default_gdb_path, "reclass")
            out_ebm = arcpy.sa.ExtractByMask(in_raster=mission_path, in_mask_data = out_raster)
            
            print(f"--Saving Clean {mission_name} to {default_gdb_path}")
            out_ebm.save(f"{default_gdb_path}\\{mission_name}")
            
            print(f"--Saving Clean {mission} to {dst}")
            out_ebm.save(dst) 
            
            #File Checks
            dste = os.path.exists(dst)
            srce = os.path.exists(src)
            

        
            if srce == True:
                if dste == False:
                    print(f"---Shutiling {mission} ---> {dst}\n")
                    shutil.move(src, dst)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")

                else:
                    print(f"---Deleting {src} - Finished Processing\n")
                    os.remove(src)
                    en = datetime.now()
                    en_str = en.strftime("%H:%M:%S")
                    
    if extension_check != 'tif': #or extension != '.db':
        if srce == True:
            if dste == False:
                print(f"-Shutiling {mission} ----> {dst}\n")
                shutil.move(src, dst)
                en = datetime.now()
                en_str = en.strftime("%H:%M:%S")
                

            else:
                print(f"-Deleting {src} - Non-Tiff\n")
                os.remove(src)
                en = datetime.now()
                en_str = en.strftime("%H:%M:%S")
                
    el_time = en - s
    print(f"+Time Elapsed: {el_time}")
    
    
def calculate_stats(mission_path):
    if extension == "tif":
        print(f"^^Calculating Statistics {mission}")
        arcpy.management.CalculateStatistics(mission_path, "", "", "", "SKIP_EXISTING", "")
    
    

if __name__ == "__main__":
    count_tot = 0
    count_tif = 0
    count_non_tif = 0
    # mm/dd/y
    start = datetime.now()
    start_time = start.strftime("%H:%M:%S")
    print(f"Start Time: {start_time}")
    #Iterating through Unprocessed Directory and retrieving Region, Sensor, and Mission
    for region in region_directory_list:
        if region != 'Thumbs.db':
            sensor_directory_list = os.listdir(os.path.join(unprocessed_directory_path, region))
            for sensor in sensor_directory_list:
                mission_directory_list = os.listdir("{}\\{}\\{}".format(unprocessed_directory_path, region, sensor))
                for mission in mission_directory_list:
                    if mission != 'Thumbs.db':
                        #print(f"mission-{mission}")
                        mission_year = mission[8:12]
                        mission_vehicle = mission[0:7]
                        extension = mission.split(".", 1)[1]
                        extension_check = mission[-3:]
                        mission_name = mission.split('.')[0]
                        mission_name = mission_name.replace("-", "_")
                        mission_path = "{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
                        if extension == 'tif':
                            count_tif += 1
                        else:
                            count_non_tif += 1
                        #Checks if the mission has been renamed; if not it is renamed
                        if region not in mission:
                            mission_altered = "{}_{}_{}.{}".format(mission_name, region, sensor, extension)
                            mission_altered_name = "{}_{}_{}".format(mission_name, region, sensor)
                            old_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission)
                            new_path = r"{}\\{}\\{}\\{}".format(unprocessed_directory_path, region, sensor, mission_altered)
                            mission_path = new_path
                            mission_name = mission_altered_name
                            mission = mission_altered
                            #print(f"Renaming Mission")
                            try:
                                os.rename(old_path, new_path)
                            except Exception as f:
                                print(f"Unable to rename {mission}")
                        
                        
                        #Validating GDB and Creating needed GDB
                        region_gdb_path = "{}\{}.gdb".format(ArcGIS_path, region)
                        gdb_create(region)
            
                        #Creating Processed Directories
                        create_processed_directories()
                    
                        print(f" \n                             **{mission}** \n")
                        count_tot += 1
                        #Adding Geotiffs to map
                        calculate_stats(mission_path)
                        
                        #Running Model
                        
                        model(mission)

                        #except Exception as e:
                            #print(f"\n !!Unable to Process {mission}\n\n")
                        

    end = datetime.now()
    end_time = end.strftime("%H:%M:%S")    
    time_elapsed = end - start
    print(f"All Processing Complete")
    print(f"---Start Time: {start_time}")
    print(f"---End Time: {end_time}")
    print(f"---Time Elapsed: {time_elapsed}")
    print(f"---Tiffs Processed: {count_tif}")
    print(f"---Tiffs Moved: {count_non_tif}")
    print(f"---Total Files: {count_tot}")

# %% [markdown]
# # Copy Raster from a GDB to File Directory
# >- This Script will take the sonar images from a GDB and move them to specified directory.
# >- Be advised this script doesn't rename the raster dataset in the GDB and the process will fail if the file starts with a number.

# %%
import arcpy
import os



workspace = r"Y:\Image_Processing\Web_Geotiffs.gdb"
arcpy.env.workspace = workspace

sensor = input("What Sensor? SSAM, MST, ATLAS, JSF:\n ")
region = input("What Region? Refer to established directories:\n ")
unprocessed_directory_path = r"Y:\TIFFs\Unprocessed_Tiffs\{}\{}".format(region, sensor)
unprocessed_list = os.listdir(unprocessed_directory_path)

if __name__ == "__main__":
    raster_list = arcpy.ListRasters()
    length = 1
    for raster in raster_list:
        raster_length = len(raster_list)
        if raster != "reclass":
            with_extension = raster + ".tif"
            out_raster = os.path.join(unprocessed_directory_path, with_extension)
            ore = os.path.exists(out_raster)
            if ore == False:
                print(f"Copying {raster} and saving to {unprocessed_directory_path}")
                print(f"{length}/{raster_length}\n")
                try:
                    arcpy.management.CopyRaster(in_raster = raster, 
                                                out_rasterdataset = out_raster,
                                                config_keyword = '',
                                                background_value = None,
                                                nodata_value = 255,
                                                onebit_to_eightbit = "NONE",
                                                colormap_to_RGB = "NONE",
                                                pixel_type = "32_BIT_UNSIGNED",
                                                scale_pixel_value = "NONE",
                                                RGB_to_Colormap = "NONE",
                                                format = "TIFF",
                                                transform = "NONE",
                                                process_as_multidimensional = "CURRENT_SLICE",
                                                build_multidimensional_transpose = "NO_TRANSPOSE")
                except Exception as e:
                    print("Unable to Copy\n")
                
            else:
                print(f"{raster} has already been processed")
            
            length += 1
    print("\nFinished\n")

# %% [markdown]
# # Functions to Help With Renaming
# >- These functions need to altered to fit situations

# %%
def rename_copy():
    arcpy.env.workspace = "Y:\Image_Processing\Web_Geotiffs.gdb"
    copy_list = arcpy.ListRasters("copy*")
    for r in copy_list:
        print(r)
        if "IVER3" not in r: 
            u_count = r.count("_")
            if u_count == 2:
                split = r.split("_")
                split_len = len(split)
                copy = split[0]
                date = split[1]
                sn = split[2]
                rename = "{}_{}".format(sn,date)
                print(f"{rename}\n")
                try:
                    arcpy.Rename_management(r, rename)
                except Exception as e:
                    print(f"Failed {r}\n")
            else:
                split = r.split("_",3)
                split_len = len(split)
                copy = split[0]
                date = split[1]
                sn = split[2]
                rest = split[3]
                rename = "{}_{}_{}".format(sn,date,rest)
                print(f"{rename}\n")
                try:
                    arcpy.Rename_management(r, rename)
                except Exception as e:
                    print(f"Failed {r}\n")
        else:
            rename = r.replace("_IVER3_3049", "")
            rename = rename.replace("copy", "IVER3_3049")
            print(rename)
            arcpy.Rename_management(r,rename)
rename_copy()

# %% [markdown]
# # Building Pyramids on Processed Geotiffs
# Use this script for building pyramids for already processed geotiffs. Pyramids need to be rebuilt for the background scrub to take effect.

# %%
directory = r"Y:\TIFFs\Processed_Tiffs"
for root, dirs, file in os.walk(directory):
    for f in file:
        ext = f.split(".", 1)[1]
        if ext == 'tif':
            vehicle = f.split("_")[0]
            year = f[8:12]
            region = f.split("_")[-2]
            f_name = f.split(".")[0]
            sensor = f_name[-3:]
            ovr_path = "{}\{}\{}\{}\{}\{}.tif.ovr".format(directory, region, sensor, vehicle, year, f_name)
            ope = os.path.exists(ovr_path)
            f_path = "{}\{}\{}\{}\{}\{}".format(directory, region, sensor, vehicle, year, f)
            if ope == False:
                try:
                    print(f"--Building Pyramids {f}")
                    arcpy.management.BuildPyramids(f_path, (-1))
                except Exception as e:
                    print(f"--Unable to Build Pyramids {f}")
# Out:
# --Building Pyramids SN01556_20210626_DR2.tif
# --Unable to Build Pyramids SN01556_20210626_DR2.tif
# --Building Pyramids SN01556_20210628_DR1_ArabianGulf_MST.tif
# --Building Pyramids SN01557_20210402_DR2.tif
# --Unable to Build Pyramids SN01557_20210402_DR2.tif
# --Building Pyramids SN01557_20210803.tif
# --Unable to Build Pyramids SN01557_20210803.tif
# --Building Pyramids SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06231_20150216_SSAM_007_1_ArabianGulf_SSAM.tif
# --Building Pyramids SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06231_20150216_SSAM_007_ArabianGulf_SSAM.tif
# --Building Pyramids SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06231_20150217_SSAM_007_ArabianGulf_SSAM.tif
# --Building Pyramids SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06231_20150302_SSAM_007_ArabianGulf_SSAM.tif
# --Building Pyramids SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06232_20150106_SSAM_004_ArabianGulf_SSAM.tif
# --Building Pyramids SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06232_20150224_SSAM_008_ArabianGulf_SSAM.tif
# --Building Pyramids SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06232_20150302_SSAM_008_ArabianGulf_SSAM.tif
# --Building Pyramids SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06234_20150216_SSAM_005_ArabianGulf_SSAM.tif
# --Building Pyramids SN06269_20170228_SSAM_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06269_20170228_SSAM_ArabianGulf_SSAM.tif
# --Building Pyramids SN06285_20170423_SSAM_ArabianGulf_SSAM.tif
# --Unable to Build Pyramids SN06285_20170423_SSAM_ArabianGulf_SSAM.tif
# --Building Pyramids SN06224_20170110_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06224_20170110_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06224_20170803_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06224_20170803_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06225_20140708_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06225_20140708_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180316_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180316_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180316_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180316_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180320_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180320_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180320_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180320_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180322_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180322_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180322_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180322_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180327_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180327_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180327_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180327_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180327_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180327_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180327_ATLAS_4_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180327_ATLAS_4_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180327_ATLAS_5_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180327_ATLAS_5_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180327_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180327_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180403_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180403_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180405_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180405_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180405_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180405_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_4_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_4_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_5_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_5_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_6_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_6_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_7_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_7_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180418_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180418_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180502_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180502_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180504_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180504_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_4_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_4_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_5_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_5_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_6_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_6_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_7_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_7_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180509_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180509_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180516_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180516_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06227_20180516_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06227_20180516_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06231_20220105_float_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06231_20220105_float_SanDiego_ATLAS.tif
# --Building Pyramids SN06231_20220105_gray_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06231_20220105_gray_SanDiego_ATLAS.tif
# --Building Pyramids SN06231_20220105_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06231_20220105_SanDiego_ATLAS.tif
# --Building Pyramids SN06232_20170928_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06232_20170928_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06232_20171206_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06232_20171206_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180316_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180316_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180316_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180316_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180320_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180320_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180327_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180327_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180327_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180327_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180327_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180327_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180329_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180329_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180329_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180329_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180329_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180329_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06255_20180329_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06255_20180329_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20170831_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20170831_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20171117_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20171117_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20171117_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20171117_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180206_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180206_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180509_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180509_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180509_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180509_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180509_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180509_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180509_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180509_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180516_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180516_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06256_20180516_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06256_20180516_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20161122_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20161122_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20161129_007_2m_res_IPOE_cd_Amplitude_RGBA_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20161129_007_2m_res_IPOE_cd_Amplitude_RGBA_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20161129_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20161129_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170405_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170405_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170405_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170405_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170405_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170405_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170405_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170405_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170608_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170608_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170608_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170608_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170608_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170608_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170608_ATLAS_4_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170608_ATLAS_4_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170608_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170608_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170627_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170627_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170706_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170706_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06288_20170803_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06288_20170803_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06298_20180215_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06298_20180215_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06298_20180215_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06298_20180215_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06298_20180405_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06298_20180405_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06298_20180405_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06298_20180405_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06299_20171019_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06299_20171019_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06299_20171019_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06299_20171019_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06299_20171019_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06299_20171019_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06299_20171206_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06299_20171206_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170530_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170530_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170530_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170530_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170530_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170530_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170530_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170530_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_4_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_4_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_5_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_5_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_6_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_6_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170608_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170608_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170627_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170627_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20170706_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20170706_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20171117_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20171117_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06303_20171117_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06303_20171117_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06318_20190507_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06318_20190507_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06318_20190507_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06318_20190507_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20180507_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20180507_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20180507_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20180507_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20180507_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20180507_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20180507_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20180507_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190507_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190507_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_1_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_1_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_2_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_2_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_3_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_3_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_4_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_4_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_5_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_5_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_7_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_7_SanDiego_ATLAS.tif
# --Building Pyramids SN06319_20190515_ATLAS_SanDiego_ATLAS.tif
# --Unable to Build Pyramids SN06319_20190515_ATLAS_SanDiego_ATLAS.tif
# --Building Pyramids SN06222_20120522_SanDiego_JSF.tif
# --Building Pyramids SN06225_20120921_1_SanDiego_JSF.tif
# --Building Pyramids SN06225_20120921_SanDiego_JSF.tif
# --Building Pyramids SN06237_20150423_SanDiego_JSF.tif
# --Building Pyramids SN06318_20210119_DARCATLAS_012_GAT_SCM_ALPHA_SanDiego_JSF.tif
# --Building Pyramids SN06318_20210406_DARCATLAS_030_SCM_EXFIL_IBF_SanDiego_JSF.tif
# --Building Pyramids SN06318_20210427_DARCATLAS_030_SCM_AO_IBF_SanDiego_JSF.tif
# --Building Pyramids SN06318_20210511_DARCATLAS_030_IPOE_EXFIL_AMCM1_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210202_DARCATLAS_012_GAT_VSW_SCM_INDIA_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210208_DARCATLAS_012_GAT_SCM_IB_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210217_DARCATLAS_013_GAT_SCM_IB_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210224_DARCATLAS_013_SCM_EXFIL_RETASK_RI_ALPHA_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210315_DARCATLAS_013_SCM_EXFIL_RETASK_ALPHA_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210331_DARCATLAS_013_SCM_EXFIL_RETASK_RI_ALPHA_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210511_DARCATLAS_013_IPOE_EXFIL_AMCM5_SanDiego_JSF.tif
# --Building Pyramids SN06319_20210519_DARCATLAS_013_SCM_ALITUDE_TEST_IBf_SanDiego_JSF.tif
# --Building Pyramids SN06320_20200810_RED_GPSFIX_1_SanDiego_JSF.tif
# --Building Pyramids SN06320_20200810_RED_GPSFIX_2_SanDiego_JSF.tif
# --Building Pyramids SN06320_20200810_RED_GPSFIX_3_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210303_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210310_152943_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210520_153432_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210819_151307_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210819_164711_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210825_151632_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210825_182102_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210827_145212_SanDiego_JSF.tif
# --Building Pyramids SN06320_20210909_154249_SanDiego_JSF.tif
# --Building Pyramids SN06357_20210929_LADDER2K_SanDiego_JSF.tif
# --Building Pyramids SN06357_20211006_ALPHA_GAT_SanDiego_JSF.tif
# --Building Pyramids SN06358_20210929_LADDER2K_SanDiego_JSF.tif
# --Building Pyramids SN06358_20211006_ALPHA_GAT_SanDiego_JSF.tif
# --Building Pyramids SN01280_20150527_2_SanDiego_MST.tif
# --Building Pyramids SN01280_20150603_SanDiego_MST.tif
# --Building Pyramids SN01338_20190213_IBF_MR4_SanDiego_MST.tif
# --Building Pyramids SN01338_20190305_MR4_NeptuneRegression_SanDiego_MST.tif
# --Building Pyramids SN01338_20190610_MR4_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01338_20190621_MR4_SCM_SanDiego_MST.tif
# --Building Pyramids SN01338_20190626_MR4_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01338_20190702_162336_SanDiego_MST.tif
# --Building Pyramids SN01338_20190717_164752_SanDiego_MST.tif
# --Building Pyramids SN01338_20190923_MR4COLLAB_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01338_20190927_150356_SanDiego_MST.tif
# --Building Pyramids SN01338_20190930_163553_SanDiego_MST.tif
# --Building Pyramids SN01338_20191016_151859_SanDiego_MST.tif
# --Building Pyramids SN01338_20191108_INDIA_MR4_TestDay2_SanDiego_MST.tif
# --Building Pyramids SN01338_20191113_INDIA_MR4_SanDiego_MST.tif
# --Building Pyramids SN01390_131024_SanDiego_MST.tif
# --Building Pyramids SN01390_140415_SanDiego_MST.tif
# --Building Pyramids SN01390_140429_SanDiego_MST.tif
# --Building Pyramids SN01390_140610_SanDiego_MST.tif
# --Building Pyramids SN01390_140624_SanDiego_MST.tif
# --Building Pyramids SN01390_20131105_SanDiego_MST.tif
# --Building Pyramids SN01390_20131107_SanDiego_MST.tif
# --Building Pyramids SN01390_20131113_SanDiego_MST.tif
# --Building Pyramids SN01390_20131119_SanDiego_MST.tif
# --Building Pyramids SN01390_20140130_1_SanDiego_MST.tif
# --Building Pyramids SN01390_20140211_SanDiego_MST.tif
# --Building Pyramids SN01390_20140213_SanDiego_MST.tif
# --Building Pyramids SN01390_20140402_SanDiego_MST.tif
# --Building Pyramids SN01390_20140422_SanDiego_MST.tif
# --Building Pyramids SN01390_20140529_SanDiego_MST.tif
# --Building Pyramids SN01390_20140612_SanDiego_MST.tif
# --Building Pyramids SN01390_20140617_SanDiego_MST.tif
# --Building Pyramids SN01439_20140910_INS_SanDiego_MST.tif
# --Building Pyramids SN01439_20140915_Transponder_India_SanDiego_MST.tif
# --Building Pyramids SN01439_20140917_deepwater_alpha_SanDiego_MST.tif
# --Building Pyramids SN01439_20140918_Endurance_India_SanDiego_MST.tif
# --Building Pyramids SN01439_20150421_1_SanDiego_MST.tif
# --Building Pyramids SN01439_20150422_T2M1_SanDiego_MST.tif
# --Building Pyramids SN01439_20150709_1_SanDiego_MST.tif
# --Building Pyramids SN01439_20151202_SanDiego_MST.tif
# --Building Pyramids SN01439_20151229_SanDiego_MST.tif
# --Building Pyramids SN01439_20160322_1_SanDiego_MST.tif
# --Building Pyramids SN01439_20160405_SanDiego_MST.tif
# --Building Pyramids SN01440_20140821_Endurance_India_SanDiego_MST.tif
# --Building Pyramids SN01440_20140825_Transponder_India_SanDiego_MST.tif
# --Building Pyramids SN01440_20140904_FinalCheck_SanDiego_MST.tif
# --Building Pyramids SN01440_20150421_SanDiego_MST.tif
# --Building Pyramids SN01440_20150422_T2M1_SanDiego_MST.tif
# --Building Pyramids SN01440_20150618_1_SanDiego_MST.tif
# --Building Pyramids SN01440_20150706_SanDiego_MST.tif
# --Building Pyramids SN01440_20150709_1_SanDiego_MST.tif
# --Building Pyramids SN01440_20150903_team2_SanDiego_MST.tif
# --Building Pyramids SN01440_20150910_01_SanDiego_MST.tif
# --Building Pyramids SN01440_20151202_SanDiego_MST.tif
# --Building Pyramids SN01440_20160209_1_SanDiego_MST.tif
# --Building Pyramids SN01460_20150713_SanDiego_MST.tif
# --Building Pyramids SN01460_20150715_SanDiego_MST.tif
# --Building Pyramids SN01460_20150717_SanDiego_MST.tif
# --Building Pyramids SN01460_20180314_145707_clip_SanDiego_MST.tif
# --Building Pyramids SN01460_20180314_145707_SanDiego_MST.tif
# --Building Pyramids SN01460_20190213_IBF_MR4_SanDiego_MST.tif
# --Building Pyramids SN01460_20190305_MR4_NeptuneRegression_SanDiego_MST.tif
# --Building Pyramids SN01460_20190312_ShortTurn_IBF_SanDiego_MST.tif
# --Building Pyramids SN01460_20190509_160136_SanDiego_MST.tif
# --Building Pyramids SN01460_20190606_154342_SanDiego_MST.tif
# --Building Pyramids SN01460_20190607_145133_SanDiego_MST.tif
# --Building Pyramids SN01460_20190610_MR4_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01460_20190617_MR4_IBC_SanDiego_MST.tif
# --Building Pyramids SN01460_20190621_MR4_SCM_SanDiego_MST.tif
# --Building Pyramids SN01460_20190702_160846_SanDiego_MST.tif
# --Building Pyramids SN01460_20190712_MR4_IBC_SHAKEDOWN_SanDiego_MST.tif
# --Building Pyramids SN01460_20190715_MR4_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01460_20190717_171039_SanDiego_MST.tif
# --Building Pyramids SN01460_20190719_MR4_INC2LAND_SanDiego_MST.tif
# --Building Pyramids SN01460_20190723_MR4_ALPHAPIPE_SanDiego_MST.tif
# --Building Pyramids SN01460_20190724_MR4_AMCM_SanDiego_MST.tif
# --Building Pyramids SN01460_20190730_SanDiego_MST.tif
# --Building Pyramids SN01460_20190731_INDIA_COLLAB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190812_ALPHAPIPE_COLLAB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190906_MR4_IB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190909_MR4_IB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190911_MR4_IB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190916_MR4_IB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190918_MR4_IB_SanDiego_MST.tif
# --Building Pyramids SN01460_20190923_MR4COLLAB_INDA_SanDiego_MST.tif
# --Building Pyramids SN01460_20190927_150645_SanDiego_MST.tif
# --Building Pyramids SN01460_20190930_163953_SanDiego_MST.tif
# --Building Pyramids SN01460_20191002_MR4_AMCM12_SanDiego_MST.tif
# --Building Pyramids SN01460_20191009_MR4_AMCM_SanDiego_MST.tif
# --Building Pyramids SN01460_20191016_150917_SanDiego_MST.tif
# --Building Pyramids SN01460_20191023_AMCM13_SanDiego_MST.tif
# --Building Pyramids SN01460_20191108_INDIA_MR4_TestDay2_SanDiego_MST.tif
# --Building Pyramids SN01460_20191113_INDIA_MR4_SanDiego_MST.tif
# --Building Pyramids SN01465_20150916_SanDiego_MST.tif
# --Building Pyramids SN01465_20150917_SanDiego_MST.tif
# --Building Pyramids SN01465_20150922_SanDiego_MST.tif
# --Building Pyramids SN01465_20150924_SanDiego_MST.tif
# --Building Pyramids SN01465_20150929_1_SanDiego_MST.tif
# --Building Pyramids SN01465_20151001_1_SanDiego_MST.tif
# --Building Pyramids SN01465_20151001_2_SanDiego_MST.tif
# --Building Pyramids SN01466_20150916_SanDiego_MST.tif
# --Building Pyramids SN01466_20150917_SanDiego_MST.tif
# --Building Pyramids SN01466_20150922_SanDiego_MST.tif
# --Building Pyramids SN01466_20151001_SanDiego_MST.tif
# --Building Pyramids SN01468_20160111_SanDiego_MST.tif
# --Building Pyramids SN01468_20160113_SanDiego_MST.tif
# --Building Pyramids SN01468_20160115_SanDiego_MST.tif
# --Building Pyramids SN01468_20160119_GAT_SanDiego_MST.tif
# --Building Pyramids SN01468_20160127_SanDiego_MST.tif
# --Building Pyramids SN01468_20160315_SanDiego_MST.tif
# --Building Pyramids SN01469_20160111_SanDiego_MST.tif
# --Building Pyramids SN01469_20160115_SanDiego_MST.tif
# --Building Pyramids SN01470_20150111_SanDiego_MST.tif
# --Building Pyramids SN01470_20160127_SanDiego_MST.tif
# --Building Pyramids SN01471_20160208_SanDiego_MST.tif
# --Building Pyramids SN01471_20160212_SanDiego_MST.tif
# --Building Pyramids SN01471_20160302_SanDiego_MST.tif
# --Building Pyramids SN01472_20160208_SanDiego_MST.tif
# --Building Pyramids SN01472_20160212_SanDiego_MST.tif
# --Building Pyramids SN01472_20160225_SanDiego_MST.tif
# --Building Pyramids SN01473_20160208_SanDiego_MST.tif
# --Building Pyramids SN01473_20160219_SanDiego_MST.tif
# --Building Pyramids SN01473_20160223_ALPHA_SanDiego_MST.tif
# --Building Pyramids SN01473_20160225_SanDiego_MST.tif
# --Building Pyramids SN01474_20160325_SanDiego_MST.tif
# --Building Pyramids SN01474_20160406_SanDiego_MST.tif
# --Building Pyramids SN01474_20160408_SanDiego_MST.tif
# --Building Pyramids SN01474_20160503_SanDiego_MST.tif
# --Building Pyramids SN01474_20160505_SanDiego_MST.tif
# --Building Pyramids SN01474_260325_SanDiego_MST.tif
# --Building Pyramids SN01475_20160323_SanDiego_MST.tif
# --Building Pyramids SN01475_20160325_SanDiego_MST.tif
# --Building Pyramids SN01475_20160406_SanDiego_MST.tif
# --Building Pyramids SN01475_20160408_SanDiego_MST.tif
# --Building Pyramids SN01476_20160323_SanDiego_MST.tif
# --Building Pyramids SN01476_20160419_SanDiego_MST.tif
# --Building Pyramids SN01476_20160503_SanDiego_MST.tif
# --Building Pyramids SN01476_20160505_SanDiego_MST.tif
# --Building Pyramids SN01476_20161025_SanDiego_MST.tif
# --Building Pyramids SN01476_20161104_SanDiego_MST.tif
# --Building Pyramids SN01480_20160602_SanDiego_MST.tif
# --Building Pyramids SN01480_20160606_SanDiego_MST.tif
# --Building Pyramids SN01480_20160613_SanDiego_MST.tif
# --Building Pyramids SN01480_20160617_SanDiego_MST.tif
# --Building Pyramids SN01481_20160602_SanDiego_MST.tif
# --Building Pyramids SN01481_20160606_SanDiego_MST.tif
# --Building Pyramids SN01481_20160615_SanDiego_MST.tif
# --Building Pyramids SN01482_20160602_SanDiego_MST.tif
# --Building Pyramids SN01482_20160606_SanDiego_MST.tif
# --Building Pyramids SN01482_20160613_SanDiego_MST.tif
# --Building Pyramids SN01483_20160622_SanDiego_MST.tif
# --Building Pyramids SN01483_20160624_Alpha_SanDiego_MST.tif
# --Building Pyramids SN01483_20160629_SanDiego_MST.tif
# --Building Pyramids SN01484_20160622_SanDiego_MST.tif
# --Building Pyramids SN01484_20160629_SanDiego_MST.tif
# --Building Pyramids SN01485_20160622_SanDiego_MST.tif
# --Building Pyramids SN01485_20160629_SanDiego_MST.tif
# --Building Pyramids SN01486_20160802_LBL_SanDiego_MST.tif
# --Building Pyramids SN01486_20160803_DR_SanDiego_MST.tif
# --Building Pyramids SN01486_20160808_DWT_SanDiego_MST.tif
# --Building Pyramids SN01486_20160811_DR_SanDiego_MST.tif
# --Building Pyramids SN01487_20160725_DWT_SanDiego_MST.tif
# --Building Pyramids SN01487_20160802_LBL_SanDiego_MST.tif
# --Building Pyramids SN01488_20160727_DR_SanDiego_MST.tif
# --Building Pyramids SN01488_20160802_LBL_SanDiego_MST.tif
# --Building Pyramids SN01488_20160811_LBL_SanDiego_MST.tif
# --Building Pyramids SN01489_20160826_DR_SanDiego_MST.tif
# --Building Pyramids SN01489_20160830_DR_SanDiego_MST.tif
# --Building Pyramids SN01489_20160830_SanDiego_MST.tif
# --Building Pyramids SN01489_20160907_LBL_SanDiego_MST.tif
# --Building Pyramids SN01490_20160830_DR_SanDiego_MST.tif
# --Building Pyramids SN01490_20160830_SanDiego_MST.tif
# --Building Pyramids SN01490_20160907_LBL_SanDiego_MST.tif
# --Building Pyramids SN01491_20160830_DR_SanDiego_MST.tif
# --Building Pyramids SN01491_20160830_SanDiego_MST.tif
# --Building Pyramids SN01491_20160907_LBL_SanDiego_MST.tif
# --Building Pyramids SN01492_20160929_SanDiego_MST.tif
# --Building Pyramids SN01492_20161005_LBL_SanDiego_MST.tif
# --Building Pyramids SN01493_20160929_SanDiego_MST.tif
# --Building Pyramids SN01493_20161005_LBL_SanDiego_MST.tif
# --Building Pyramids SN01494_20160929_SanDiego_MST.tif
# --Building Pyramids SN01494_20161005_LBL_SanDiego_MST.tif
# --Building Pyramids SN01495_20161024_SanDiego_MST.tif
# --Building Pyramids SN01495_20161104_SanDiego_MST.tif
# --Building Pyramids SN01495_20180215_MR2_RI_LM_SanDiego_MST.tif
# --Building Pyramids SN01495_20180521_1_SanDiego_MST.tif
# --Building Pyramids SN01495_20180521_2_SanDiego_MST.tif
# --Building Pyramids SN01495_20180523_INCII_Field_SanDiego_MST.tif
# --Building Pyramids SN01495_20190530_WHISKEY_1_SanDiego_MST.tif
# --Building Pyramids SN01495_20190530_WHISKEY_SanDiego_MST.tif
# --Building Pyramids SN01495_20190606_WHISKEY_SanDiego_MST.tif
# --Building Pyramids SN01496_20161024_SanDiego_MST.tif
# --Building Pyramids SN01496_20161108_SanDiego_MST.tif
# --Building Pyramids SN01497_20161025_SanDiego_MST.tif
# --Building Pyramids SN01497_20200922_INDIA_NEXUSMM_SanDiego_MST.tif
# --Building Pyramids SN01512_20170918_2kGAT_SanDiego_MST.tif
# --Building Pyramids SN01512_20170928_SWT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01513_20170918_2kGAT_SanDiego_MST.tif
# --Building Pyramids SN01513_20170928_SWT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01514_20170918_2kGAT_SanDiego_MST.tif
# --Building Pyramids SN01514_20170928_SWT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01515_20170918_2kGAT_SanDiego_MST.tif
# --Building Pyramids SN01515_20170926_ALPHA_DWT_SanDiego_MST.tif
# --Building Pyramids SN01515_20170928_SWT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01520_20180816_RI_DR_SanDiego_MST.tif
# --Building Pyramids SN01520_20180822_DWT_SanDiego_MST.tif
# --Building Pyramids SN01520_20180824_GWB_SanDiego_MST.tif
# --Building Pyramids SN01520_20180828_SS_SanDiego_MST.tif
# --Building Pyramids SN01520_20180830_SS_SanDiego_MST.tif
# --Building Pyramids SN01520_20180904_SS_SanDiego_MST.tif
# --Building Pyramids SN01520_20180906_SS_SanDiego_MST.tif
# --Building Pyramids SN01520_20180926_GATS_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01521_20180814_DR_SanDiego_MST.tif
# --Building Pyramids SN01521_20180820_SWT_SanDiego_MST.tif
# --Building Pyramids SN01521_20180822_DWT_SanDiego_MST.tif
# --Building Pyramids SN01522_20180814_DR_SanDiego_MST.tif
# --Building Pyramids SN01522_20180820_SWT_SanDiego_MST.tif
# --Building Pyramids SN01522_20180822_DWT_SanDiego_MST.tif
# --Building Pyramids SN01523_20180904_DR_SanDiego_MST.tif
# --Building Pyramids SN01523_20180910_LBL_SanDiego_MST.tif
# --Building Pyramids SN01523_20180912_DWT_SanDiego_MST.tif
# --Building Pyramids SN01523_20190307_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01523_20190311_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01523_20190411_IBF_SanDiego_MST.tif
# --Building Pyramids SN01524_20180904_DR_SanDiego_MST.tif
# --Building Pyramids SN01524_20180910_LBL_SanDiego_MST.tif
# --Building Pyramids SN01524_20180912_DWT_SanDiego_MST.tif
# --Building Pyramids SN01524_20180914_GBTest_SanDiego_MST.tif
# --Building Pyramids SN01524_20180926_GATS_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01524_20181002_SS_SanDiego_MST.tif
# --Building Pyramids SN01524_20181003_SanDiego_MST.tif
# --Building Pyramids SN01524_20181010_SanDiego_MST.tif
# --Building Pyramids SN01524_20181016_SStest_SanDiego_MST.tif
# --Building Pyramids SN01524_20181029_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01524_20181219_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01524_20190318_INDIACENTER_SanDiego_MST.tif
# --Building Pyramids SN01524_20190325_Bassets_SanDiego_MST.tif
# --Building Pyramids SN01524_20190411_IBF_SanDiego_MST.tif
# --Building Pyramids SN01524_20190415_IBF_SanDiego_MST.tif
# --Building Pyramids SN01525_20180904_DR_SanDiego_MST.tif
# --Building Pyramids SN01525_20180910_LBL_SanDiego_MST.tif
# --Building Pyramids SN01525_20180920_transducertest_SanDiego_MST.tif
# --Building Pyramids SN01525_20190307_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01527_20181002_DR_SanDiego_MST.tif
# --Building Pyramids SN01527_20181010_SanDiego_MST.tif
# --Building Pyramids SN01527_20190307_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01527_20190408_BF_SanDiego_MST.tif
# --Building Pyramids SN01528_20181010_SanDiego_MST.tif
# --Building Pyramids SN01528_20181016_SanDiego_MST.tif
# --Building Pyramids SN01528_20181017_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20181018_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20181022_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20181024_ShallowTrans_SanDiego_MST.tif
# --Building Pyramids SN01528_20181025_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20181029_INDIA_1_SanDiego_MST.tif
# --Building Pyramids SN01528_20181113_INDIACENTER_SanDiego_MST.tif
# --Building Pyramids SN01528_20181113_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20181120_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20181121_SanDiego_MST.tif
# --Building Pyramids SN01528_20181127_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20190107_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01528_20190311_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01528_20190314_SStest_IBC_SanDiego_MST.tif
# --Building Pyramids SN01528_20190320_SSTest_SanDiego_MST.tif
# --Building Pyramids SN01528_20190320_SS_Test_SanDiego_MST.tif
# --Building Pyramids SN01528_20190408_IBF_SanDiego_MST.tif
# --Building Pyramids SN01529_20181002_DR_SanDiego_MST.tif
# --Building Pyramids SN01529_20181010_SanDiego_MST.tif
# --Building Pyramids SN01529_20181016_SanDiego_MST.tif
# --Building Pyramids SN01529_20181024_ShallowTrans_SanDiego_MST.tif
# --Building Pyramids SN01529_20181031_INDIA_GWBTEST_SanDiego_MST.tif
# --Building Pyramids SN01529_20190311_SStest_IBF_SanDiego_MST.tif
# --Building Pyramids SN01529_20190321_IBF_SanDiego_MST.tif
# --Building Pyramids SN01529_20190408_IBF_SanDiego_MST.tif
# --Building Pyramids SN01529_20190411_IBF_SanDiego_MST.tif
# --Building Pyramids SN01537_20190711_GAT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01537_20190722_GAT_SWT_SanDiego_MST.tif
# --Building Pyramids SN01537_20190724_GAT_INDIAC_SanDiego_MST.tif
# --Building Pyramids SN01537_20190806_NOVCR_SanDiego_MST.tif
# --Building Pyramids SN01537_20190806_VCRRUN_SanDiego_MST.tif
# --Building Pyramids SN01537_20190807_HOTEL_NOVCR_SanDiego_MST.tif
# --Building Pyramids SN01537_20190807_VCRUN_Hotel_SanDiego_MST.tif
# --Building Pyramids SN01537_20190812_GAT_INDIACNOVCR_SanDiego_MST.tif
# --Building Pyramids SN01537_20190812_GAT_INDIACVCR_SanDiego_MST.tif
# --Building Pyramids SN01537_20190813_INDIAC_NOVCR_SanDiego_MST.tif
# --Building Pyramids SN01537_20190813_INDIAC_VCR_SanDiego_MST.tif
# --Building Pyramids SN01538_20190711_GAT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01538_20190716_GAT_ALPHA_DT_SanDiego_MST.tif
# --Building Pyramids SN01538_20190926_INDIA_GAT_LBLscm_RI_SanDiego_MST.tif
# --Building Pyramids SN01539_20190711_GAT_INDIA_SanDiego_MST.tif
# --Building Pyramids SN01539_20190722_GAT_SWT_SanDiego_MST.tif
# --Building Pyramids SN01539_20190730_GAT_IBF_SanDiego_MST.tif
# --Building Pyramids SN01539_20190806_VCRRUN_SanDiego_MST.tif
# --Building Pyramids SN01539_20190807_HOTEL_NOVCR_SanDiego_MST.tif
# --Building Pyramids SN01539_20190807_HOTEL_VCR_SanDiego_MST.tif
# --Building Pyramids SN01539_20190812_GAT_INDIACNOVCR_SanDiego_MST.tif
# --Building Pyramids SN01539_20190813_INDIAC_NOVCR_SanDiego_MST.tif
# --Building Pyramids SN01544_20210714_SanDiego_MST.tif
# --Building Pyramids SN01563_20210115_182245_SanDiego_MST.tif
# --Building Pyramids SN01565_20210113_181053_SanDiego_MST.tif
# --Building Pyramids SN06209_20151120_SSAM2_001_India_ATR_SCM1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20151120_SSAM2_001_India_ATR_SCM1_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20160325_SSAM2_001_IB_ATR_SCM3_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20160325_SSAM2_001_IB_ATR_SCM3_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20160412_SSAM2_001_IB_ATR_SCM6_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20160412_SSAM2_001_IB_ATR_SCM6_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20160511_SSAM2_001_IB_ATR_SCM8_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20160511_SSAM2_001_IB_ATR_SCM8_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20160523_SSAM2_001_IB_LF_SCM3_BL_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20160523_SSAM2_001_IB_LF_SCM3_BL_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20160914_SSAM2_014_IB_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20160914_SSAM2_014_IB_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20170607_SSAM2_002_INDIA_SCM_PD0_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20170607_SSAM2_002_INDIA_SCM_PD0_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20170724_SSAM2_001_REDHAT_INDIAWEST_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20170724_SSAM2_001_REDHAT_INDIAWEST_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06209_20170726_SSAM2_001_INDIA_SCM_REDHAT_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06209_20170726_SSAM2_001_INDIA_SCM_REDHAT_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20140521_SSAM2_003_INDIA_ALPHA_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20140521_SSAM2_003_INDIA_ALPHA_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20140530_SSAM2_006_INDIA_ALPHA_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20140530_SSAM2_006_INDIA_ALPHA_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20140605_013604_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20140605_013604_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20151117_SSAM2_002_India_ATRTuning_Cylinder_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20151117_SSAM2_002_India_ATRTuning_Cylinder_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20151202_SSAM2_002_India_ATR_SCM3_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20151202_SSAM2_002_India_ATR_SCM3_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20151204_SSAM2_002_India_ATR_SCM2_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20151204_SSAM2_002_India_ATR_SCM2_SanDiego_SSAM.tif
# --Building Pyramids SN06210_20160212_SSAM2_002_INDIA_ATR_SCM4_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06210_20160212_SSAM2_002_INDIA_ATR_SCM4_SanDiego_SSAM.tif
# --Building Pyramids SN06222_20210916_082527_MISSION_1_20210917_105923_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06222_20210916_082527_MISSION_1_20210917_105923_SanDiego_SSAM.tif
# --Building Pyramids SN06223_20211013_085406_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06223_20211013_085406_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06256_20140429_SSAM2_003_JULIET_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06256_20140429_SSAM2_003_JULIET_SanDiego_SSAM.tif
# --Building Pyramids SN06256_20140603_SSAM2_005_INDIA_LF_Filter_Only_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06256_20140603_SSAM2_005_INDIA_LF_Filter_Only_SanDiego_SSAM.tif
# --Building Pyramids SN06297_20171117_SSAM2_008_INDIAW_REDHAT_LFAS4LR_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06297_20171117_SSAM2_008_INDIAW_REDHAT_LFAS4LR_SanDiego_SSAM.tif
# --Building Pyramids SN06297_20180314_SSAM2_002_INDIA_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06297_20180314_SSAM2_002_INDIA_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06297_20180410_SSAM2_002_India_Sortie_01_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06297_20180410_SSAM2_002_India_Sortie_01_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06297_20180508_SSAM2_002_HOTEL_SORTIE_18_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06297_20180508_SSAM2_002_HOTEL_SORTIE_18_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06297_20180522_SSAM2_002_INDIA_SORTIE_25_SCM_NIGHT_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06297_20180522_SSAM2_002_INDIA_SORTIE_25_SCM_NIGHT_SanDiego_SSAM.tif
# --Building Pyramids SN06297_20180605_SSAM2_002_HOTEL_SCM_SORTIE_33_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06297_20180605_SSAM2_002_HOTEL_SCM_SORTIE_33_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20180319_SSAM2_08_INDIA_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20180319_SSAM2_08_INDIA_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20180522_SSAM2_008_INDIA_SCM_NIGHT_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20180522_SSAM2_008_INDIA_SCM_NIGHT_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20180702_SSAM2_003_India_SCM2_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20180702_SSAM2_003_India_SCM2_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20181023_SSAM2_008_INDIA_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20181023_SSAM2_008_INDIA_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20190109_SSAM2_001_INDIA_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20190109_SSAM2_001_INDIA_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20190111_SSAM2_017_INDIA_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20190111_SSAM2_017_INDIA_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20191011_SSAM2_009_INDIACENTER_SCM_BLUE_MSN2_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20191011_SSAM2_009_INDIACENTER_SCM_BLUE_MSN2_SanDiego_SSAM.tif
# --Building Pyramids SN06303_20200304_082232_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06303_20200304_082232_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20191211_080151_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20191211_080151_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20200304_083324_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20200304_083324_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20200304_SSAM2_016_QZR1_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20200304_SSAM2_016_QZR1_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20200313_083723_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20200313_083723_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20200313_SSAM2_016_ORANGE_BOATLANES_SCM_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20200313_SSAM2_016_ORANGE_BOATLANES_SCM_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20200317_075033_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20200317_075033_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20200317_SSAM2_016_INDIA_SCM_ATR_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20200317_SSAM2_016_INDIA_SCM_ATR_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20210930_090209_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20210930_090209_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN06323_20211006_082406_MISSION_1_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN06323_20211006_082406_MISSION_1_SanDiego_SSAM.tif
# --Building Pyramids SN20140521_SN06210_SSAM2_003_INDIA_ALPHA_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN20140521_SN06210_SSAM2_003_INDIA_ALPHA_SanDiego_SSAM.tif
# --Building Pyramids SN20140530_SN06210_SSAM2_006_INDIA_ALPHA_SanDiego_SSAM.tif
# --Unable to Build Pyramids SN20140530_SN06210_SSAM2_006_INDIA_ALPHA_SanDiego_SSAM.tif
